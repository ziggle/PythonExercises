# %% [markdown]
# This is an exercise in simulating the results from A/D converter and HPM10

# %%
from numpy import random
vBAT=3.7
adc = 0.005
#mn=0.332_750_00
#mx=0.332_968_75
mn=0.327312
mx=0.333018
rmn=1/mx
rmx = 1/mn
rng = mx-mn
print(f'min is {mn:.4f}, max is {mx:.4f}')
print(f'range is {rng/2:0.4f}')
ratio = random.uniform(mn, mx,size=10000)
#ratio = random.normal(0.332668,0.00011397,1000)
lsad=random.uniform(-adc,adc,10000)
#vbat  = random.uniform(vBAT*0.327312,vBAT*0.333018,10000)
vha = (vBAT*ratio)+lsad
print(vha.min(),vha.max(),vha.mean(),vha.max()-vha.mean(),vha.min()-vha.mean())
print(vBAT*rng/2+0.005)
print(3.7*rng/2)
# Out:
# min is 0.3273, max is 0.3330
# range is 0.0029
# 1.206207481959292 1.23692670116265 1.2215343668817622 0.01539233428088771 -0.015326884922470141
# 0.015556099999999979
# 0.01055609999999998

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
print(vha.mean())
print(vha.std())
print(vha.max()-vha.min())
sns.distplot(vha, hist=False)

plt.show()
# Out:
# 1.2215343668817622
# 0.006702786050217811
# 0.03071921920335785
# C:\Users\Mark\AppData\Local\Temp\ipykernel_11784\3141946231.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(vha, hist=False)

# %%
vHA=1.2
adc = 0.005
#mn=0.332_750_00
#mx=0.332_968_75
mn=0.327312
mx=0.333018
print(mx-mn)
rmn=1/mx
rmx = 1/mn
rng = mx-mn
print(f'min is {mn:.4f}, max is {mx:.4f}')
print(f'range is {rng/2:0.4f}')
ratio = random.uniform(mn, mx,size=10000)
#ratio = random.normal(0.332668,0.00011397,1000)
lsad=random.uniform(-adc,adc,10000)
#vbat  = random.uniform(vBAT*0.327312,vBAT*0.333018,10000)
vbat = (vHA+lsad)/ratio
print(vbat.min(),vbat.max(),vbat.mean(),vbat.max()-vbat.mean(),vbat.min()-vbat.mean())
print((1-(1+adc/1.2)/(1+rng/0.328))*3.6)
#print(3.7*rng/2)
# Out:
# 0.005705999999999989
# min is 0.3273, max is 0.3330
# range is 0.0029
# 3.588560430913911 3.6804214837972293 3.6348150805264683 0.04560640327076104 -0.04625464961255732
# 0.04681246366562202
