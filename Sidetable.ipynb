# %% [markdown]
# https://towardsdatascience.com/sidetable-gives-you-the-pandas-methods-you-didnt-know-you-needed-92be825ff512

# %%
import sys
import pandas as pd
import sidetable 

print(f"Python version {sys.version}")
print(f"pandas version: {pd.__version__}")
print(f"sidetable version: {sidetable.__version__}")
# Out:
# Python version 3.11.6 (tags/v3.11.6:8b6ee5b, Oct  2 2023, 14:57:12) [MSC v.1935 64 bit (AMD64)]
# pandas version: 2.0.2
# sidetable version: 0.9.1

# %%
df_penguins = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv')
df_penguins.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE

# %%
df_penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df_penguins.stb.missing()
# Out:
#                    missing  total   percent
# sex                     11    344  3.197674
# bill_length_mm           2    344  0.581395
# bill_depth_mm            2    344  0.581395
# flipper_length_mm        2    344  0.581395
# body_mass_g              2    344  0.581395
# species                  0    344  0.000000
# island                   0    344  0.000000

# %%
df_penguins.stb.missing(style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4f278">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f278_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_4f278_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_4f278_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f278_level0_row0" class="row_heading level0 row0" >sex</th>
#       <td id="T_4f278_row0_col0" class="data row0 col0" >11</td>
#       <td id="T_4f278_row0_col1" class="data row0 col1" >344</td>
#       <td id="T_4f278_row0_col2" class="data row0 col2" >3.20%</td>
#     </tr>
#     <tr>
#       <th id="T_4f278_level0_row1" class="row_heading level0 row1" >bill_length_mm</th>
#       <td id="T_4f278_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_4f278_row1_col1" class="data row1 col1" >344</td>
#       <td id="T_4f278_row1_col2" class="data row1 col2" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_4f278_level0_row2" class="row_heading level0 row2" >bill_depth_mm</th>
#       <td id="T_4f278_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_4f278_row2_col1" class="data row2 col1" >344</td>
#       <td id="T_4f278_row2_col2" class="data row2 col2" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_4f278_level0_row3" class="row_heading level0 row3" >flipper_length_mm</th>
#       <td id="T_4f278_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_4f278_row3_col1" class="data row3 col1" >344</td>
#       <td id="T_4f278_row3_col2" class="data row3 col2" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_4f278_level0_row4" class="row_heading level0 row4" >body_mass_g</th>
#       <td id="T_4f278_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_4f278_row4_col1" class="data row4 col1" >344</td>
#       <td id="T_4f278_row4_col2" class="data row4 col2" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_4f278_level0_row5" class="row_heading level0 row5" >species</th>
#       <td id="T_4f278_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_4f278_row5_col1" class="data row5 col1" >344</td>
#       <td id="T_4f278_row5_col2" class="data row5 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4f278_level0_row6" class="row_heading level0 row6" >island</th>
#       <td id="T_4f278_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_4f278_row6_col1" class="data row6 col1" >344</td>
#       <td id="T_4f278_row6_col2" class="data row6 col2" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_penguins.stb.freq(['species'])
# Out:
#      species  count    percent  cumulative_count  cumulative_percent
# 0     Adelie    152  44.186047               152           44.186047
# 1     Gentoo    124  36.046512               276           80.232558
# 2  Chinstrap     68  19.767442               344          100.000000

# %%
df_penguins.stb.freq(['species'], style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fe2f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe2f2_level0_col0" class="col_heading level0 col0" >species</th>
#       <th id="T_fe2f2_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_fe2f2_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_fe2f2_level0_col3" class="col_heading level0 col3" >cumulative_count</th>
#       <th id="T_fe2f2_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe2f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe2f2_row0_col0" class="data row0 col0" >Adelie</td>
#       <td id="T_fe2f2_row0_col1" class="data row0 col1" >152</td>
#       <td id="T_fe2f2_row0_col2" class="data row0 col2" >44.19%</td>
#       <td id="T_fe2f2_row0_col3" class="data row0 col3" >152</td>
#       <td id="T_fe2f2_row0_col4" class="data row0 col4" >44.19%</td>
#     </tr>
#     <tr>
#       <th id="T_fe2f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe2f2_row1_col0" class="data row1 col0" >Gentoo</td>
#       <td id="T_fe2f2_row1_col1" class="data row1 col1" >124</td>
#       <td id="T_fe2f2_row1_col2" class="data row1 col2" >36.05%</td>
#       <td id="T_fe2f2_row1_col3" class="data row1 col3" >276</td>
#       <td id="T_fe2f2_row1_col4" class="data row1 col4" >80.23%</td>
#     </tr>
#     <tr>
#       <th id="T_fe2f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe2f2_row2_col0" class="data row2 col0" >Chinstrap</td>
#       <td id="T_fe2f2_row2_col1" class="data row2 col1" >68</td>
#       <td id="T_fe2f2_row2_col2" class="data row2 col2" >19.77%</td>
#       <td id="T_fe2f2_row2_col3" class="data row2 col3" >344</td>
#       <td id="T_fe2f2_row2_col4" class="data row2 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_penguins.stb.freq(['species'], style=True, cum_cols=False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0a177">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a177_level0_col0" class="col_heading level0 col0" >species</th>
#       <th id="T_0a177_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_0a177_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a177_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a177_row0_col0" class="data row0 col0" >Adelie</td>
#       <td id="T_0a177_row0_col1" class="data row0 col1" >152</td>
#       <td id="T_0a177_row0_col2" class="data row0 col2" >44.19%</td>
#     </tr>
#     <tr>
#       <th id="T_0a177_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a177_row1_col0" class="data row1 col0" >Gentoo</td>
#       <td id="T_0a177_row1_col1" class="data row1 col1" >124</td>
#       <td id="T_0a177_row1_col2" class="data row1 col2" >36.05%</td>
#     </tr>
#     <tr>
#       <th id="T_0a177_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0a177_row2_col0" class="data row2 col0" >Chinstrap</td>
#       <td id="T_0a177_row2_col1" class="data row2 col1" >68</td>
#       <td id="T_0a177_row2_col2" class="data row2 col2" >19.77%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_penguins.stb.freq(['species', 'island', 'sex'])
# Out:
#      species     island     sex  count    percent  cumulative_count  \
# 0     Gentoo     Biscoe    MALE     61  18.318318                61
# 1     Gentoo     Biscoe  FEMALE     58  17.417417               119
# 2  Chinstrap      Dream    MALE     34  10.210210               153
# 3  Chinstrap      Dream  FEMALE     34  10.210210               187
# 4     Adelie      Dream    MALE     28   8.408408               215
# 5     Adelie      Dream  FEMALE     27   8.108108               242
# 6     Adelie  Torgersen  FEMALE     24   7.207207               266
# 7     Adelie  Torgersen    MALE     23   6.906907               289
# 8     Adelie     Biscoe    MALE     22   6.606607               311
# 9     Adelie     Biscoe  FEMALE     22   6.606607               333
#
#    cumulative_percent
# 0           18.318318
# 1           35.735736
# 2           45.945946
# 3           56.156156
# 4           64.564565
# 5           72.672673
# 6           79.879880
# 7           86.786787
# 8           93.393393
# 9          100.000000

# %%
df_penguins.stb.freq(['island'], style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c75a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c75a5_level0_col0" class="col_heading level0 col0" >island</th>
#       <th id="T_c75a5_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_c75a5_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_c75a5_level0_col3" class="col_heading level0 col3" >cumulative_count</th>
#       <th id="T_c75a5_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c75a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c75a5_row0_col0" class="data row0 col0" >Biscoe</td>
#       <td id="T_c75a5_row0_col1" class="data row0 col1" >168</td>
#       <td id="T_c75a5_row0_col2" class="data row0 col2" >48.84%</td>
#       <td id="T_c75a5_row0_col3" class="data row0 col3" >168</td>
#       <td id="T_c75a5_row0_col4" class="data row0 col4" >48.84%</td>
#     </tr>
#     <tr>
#       <th id="T_c75a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c75a5_row1_col0" class="data row1 col0" >Dream</td>
#       <td id="T_c75a5_row1_col1" class="data row1 col1" >124</td>
#       <td id="T_c75a5_row1_col2" class="data row1 col2" >36.05%</td>
#       <td id="T_c75a5_row1_col3" class="data row1 col3" >292</td>
#       <td id="T_c75a5_row1_col4" class="data row1 col4" >84.88%</td>
#     </tr>
#     <tr>
#       <th id="T_c75a5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c75a5_row2_col0" class="data row2 col0" >Torgersen</td>
#       <td id="T_c75a5_row2_col1" class="data row2 col1" >52</td>
#       <td id="T_c75a5_row2_col2" class="data row2 col2" >15.12%</td>
#       <td id="T_c75a5_row2_col3" class="data row2 col3" >344</td>
#       <td id="T_c75a5_row2_col4" class="data row2 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_penguins.stb.freq(['island'], style=True, thresh=.5)
# Out:
# C:\Users\mbieg\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sidetable\sidetable.py:90: UserWarning: thresh should be expressed as a percentage. Did you mean 50?
#   warnings.warn(
# <style type="text/css">
# </style>
# <table id="T_65422">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65422_level0_col0" class="col_heading level0 col0" >island</th>
#       <th id="T_65422_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_65422_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_65422_level0_col3" class="col_heading level0 col3" >cumulative_count</th>
#       <th id="T_65422_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65422_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65422_row0_col0" class="data row0 col0" >others</td>
#       <td id="T_65422_row0_col1" class="data row0 col1" >344</td>
#       <td id="T_65422_row0_col2" class="data row0 col2" >100.00%</td>
#       <td id="T_65422_row0_col3" class="data row0 col3" >344</td>
#       <td id="T_65422_row0_col4" class="data row0 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_penguins.stb.freq(['island'], style=True, thresh=.9)
# Out:
# C:\Users\mbieg\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sidetable\sidetable.py:90: UserWarning: thresh should be expressed as a percentage. Did you mean 90?
#   warnings.warn(
# <style type="text/css">
# </style>
# <table id="T_48d3e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48d3e_level0_col0" class="col_heading level0 col0" >island</th>
#       <th id="T_48d3e_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_48d3e_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_48d3e_level0_col3" class="col_heading level0 col3" >cumulative_count</th>
#       <th id="T_48d3e_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48d3e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48d3e_row0_col0" class="data row0 col0" >others</td>
#       <td id="T_48d3e_row0_col1" class="data row0 col1" >344</td>
#       <td id="T_48d3e_row0_col2" class="data row0 col2" >100.00%</td>
#       <td id="T_48d3e_row0_col3" class="data row0 col3" >344</td>
#       <td id="T_48d3e_row0_col4" class="data row0 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_penguins.stb.freq(['island'], style=True, thresh=.9, other_label='Other Islands')
# Out:
# C:\Users\mbieg\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sidetable\sidetable.py:90: UserWarning: thresh should be expressed as a percentage. Did you mean 90?
#   warnings.warn(
# <style type="text/css">
# </style>
# <table id="T_42139">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42139_level0_col0" class="col_heading level0 col0" >island</th>
#       <th id="T_42139_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_42139_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_42139_level0_col3" class="col_heading level0 col3" >cumulative_count</th>
#       <th id="T_42139_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42139_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42139_row0_col0" class="data row0 col0" >Other Islands</td>
#       <td id="T_42139_row0_col1" class="data row0 col1" >344</td>
#       <td id="T_42139_row0_col2" class="data row0 col2" >100.00%</td>
#       <td id="T_42139_row0_col3" class="data row0 col3" >344</td>
#       <td id="T_42139_row0_col4" class="data row0 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
freq_table = df_penguins.stb.freq(['island'])
freq_table.columns = freq_table.columns.str.title()
freq_table
# Out:
#       Island  Count    Percent  Cumulative_Count  Cumulative_Percent
# 0     Biscoe    168  48.837209               168           48.837209
# 1      Dream    124  36.046512               292           84.883721
# 2  Torgersen     52  15.116279               344          100.000000

# %%
df_penguins.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    342.000000   333
# unique          NaN     2
# top             NaN  MALE
# freq            NaN   168
# mean    4201.754386   NaN
# std      801.954536   NaN
# min     2700.000000   NaN
# 25%     3550.000000   NaN
# 50%     4050.000000   NaN
# 75%     4750.000000   NaN
# max     6300.000000   NaN

# %%
df_penguins.stb.subtotal().tail()
# Out:
#             species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 340          Gentoo  Biscoe            46.8           14.3              215.0
# 341          Gentoo  Biscoe            50.4           15.7              222.0
# 342          Gentoo  Biscoe            45.2           14.8              212.0
# 343          Gentoo  Biscoe            49.9           16.1              213.0
# grand_total     NaN     NaN         15021.3         5865.7            68713.0
#
#              body_mass_g     sex
# 340               4850.0  FEMALE
# 341               5750.0    MALE
# 342               5200.0  FEMALE
# 343               5400.0    MALE
# grand_total    1437000.0     NaN

# %%
df_penguins.groupby(['species', 'sex']).agg(dict(island='count'))
# Out:
#                   island
# species   sex
# Adelie    FEMALE      73
#           MALE        73
# Chinstrap FEMALE      34
#           MALE        34
# Gentoo    FEMALE      58
#           MALE        61

# %%
df_penguins.groupby(['species', 'sex']).agg(dict(island='count')).stb.subtotal()
# Out:
#                                   island
# Adelie      FEMALE                    73
#             MALE                      73
#             Adelie - subtotal        146
# Chinstrap   FEMALE                    34
#             MALE                      34
#             Chinstrap - subtotal      68
# Gentoo      FEMALE                    58
#             MALE                      61
#             Gentoo - subtotal        119
# grand_total                          333
