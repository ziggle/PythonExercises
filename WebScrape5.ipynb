# %% [markdown]
# https://medium.com/@gozdebarin/web-scraping-in-python-tips-and-code-examples-bbb52e81556e

# %%
#!pip install requests beautifulsoup4
import requests
from bs4 import BeautifulSoup

url = 'https://www.mathscinotes.com/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Extracting specific data
title = soup.title.text
paragraphs = soup.find_all('p')

print(f'Title: {title}')
for p in paragraphs:
    print(p.text)
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: C:\Users\mbieg\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#                                               0.0/143.0 kB ? eta -:--:--
#      ----------                            41.0/143.0 kB 960.0 kB/s eta 0:00:01
#      -----------------------------          112.6/143.0 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 143.0/143.0 kB 1.1 MB/s eta 0:00:00
# ...
# Title:
# Math Encounters Blog | I stumbled upon some math today …
# Quote of the Day
# 20 years from now, the only people who will remember that you worked late are your kids.
# — Something I saw on a Reddit post. I don't recall which one. Young parents need to remember this.
# Figure 1: Mosquito Magnet I am testing. (Amazon)
# ...

# %%
# Navigating and searching within HTML
first_link = soup.find('a')  # Find the first anchor tag
all_links = soup.find_all('a')  # Find all anchor tags

# Extracting attributes
for link in all_links:
    href = link['href']
    text = link.text
    print(f'Text: {text}, Href: {href}')
# Out:
# Text: Math Encounters Blog, Href: https://www.mathscinotes.com/
# Text: Skip to content, Href: #content
# Text: Home, Href: https://mathscinotes.com/
# Text: About, Href: https://www.mathscinotes.com/about/
# Text: ← Older posts, Href: https://www.mathscinotes.com/page/2/
# Text: Mosquito Magnet Testing, Href: https://www.mathscinotes.com/2023/07/mosquito-magnet-testing/
# Text: 24-July-2023, Href: https://www.mathscinotes.com/2023/07/mosquito-magnet-testing/
# Text: mathscinotes, Href: https://www.mathscinotes.com/author/mathscinotes/
# Text: , Href: https://i0.wp.com/www.mathscinotes.com/wp-content/uploads/2023/07/MosquitoMagnet.png?ssl=1
# Text: Amazon, Href: https://www.amazon.com/Mosquito-Magnet-MM4200B-Patriot-Plus/dp/B07CLT5D6Z/ref=asc_df_B07CLT5D6Z/?tag=hyprod-20&linkCode=df0&hvadid=241960413056&hvpos=&hvnetw=g&hvrand=10102916952523051966&hvpone=&hvptwo=&hvqmt=&hvdev=c&hvdvcmdl=&hvlocint=&hvlocphy=9019578&hvtargid=pla-455187609118&psc=1
# ...

# %%
# !pip install selenium
from selenium import webdriver

url = 'https://example.com/dynamic-content'
driver = webdriver.Chrome()  # Use the appropriate driver

driver.get(url)
dynamic_element = driver.find_element_by_id('dynamic-id')
print(dynamic_element.text)

driver.quit()  # Close the browser
# Out:
# ...
#                                               0.0/7.2 MB ? eta -:--:--
#                                               0.0/7.2 MB 1.3 MB/s eta 0:00:06
#                                               0.1/7.2 MB 1.3 MB/s eta 0:00:06
#                                               0.1/7.2 MB 1.2 MB/s eta 0:00:06
#      -                                        0.2/7.2 MB 1.2 MB/s eta 0:00:06
#      -                                        0.3/7.2 MB 1.2 MB/s eta 0:00:06
#      -                                        0.3/7.2 MB 1.2 MB/s eta 0:00:06
#      --                                       0.4/7.2 MB 1.2 MB/s eta 0:00:06
#      --                                       0.4/7.2 MB 1.1 MB/s eta 0:00:06
#      --                                       0.5/7.2 MB 1.2 MB/s eta 0:00:06
#      --                                       0.5/7.2 MB 1.2 MB/s eta 0:00:06
#      ---                                      0.6/7.2 MB 1.2 MB/s eta 0:00:06
# ...

# %%
for page_number in range(1, 6):
    url = f'https://example.com/page/{page_number}'
    response = requests.get(url)
    # Process the response and extract data
