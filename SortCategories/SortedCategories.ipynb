# %% [markdown]
# https://twitter.com/__mharrison__/status/1643629653049987079/photo/1

# %%
import pandas as pd
crimes=pd.read_csv("data.csv")
crimes.head()
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE  0870
# 2  11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE  0810
# 3  10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE  2023
# 4  10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE  0560
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 2        THEFT                OVER $500            RESIDENCE   False
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 4      ASSAULT                   SIMPLE            APARTMENT   False
#
#    Domestic  ...  Ward  Community Area  FBI Code  X Coordinate Y Coordinate  \
# ...

# %%
(crimes
  .sample(500)
  .assign(month_name=lambda df:pd.to_datetime(df['Date']).dt.month_name())
  .pipe(lambda df:pd.crosstab(index=df['Primary Type'],columns=df.month_name))
)
# Out:
# month_name                        April  August  December  January  July  \
# Primary Type
# ARSON                                 0       0         0        0     0
# ASSAULT                               0       1         0        0     0
# BATTERY                               1       2         0        0     0
# BURGLARY                              0       1         0        0     0
# CRIM SEXUAL ASSAULT                   0       0         1        1     0
# CRIMINAL DAMAGE                       1       1         0        0     0
# CRIMINAL TRESPASS                     0       0         0        0     0
# DECEPTIVE PRACTICE                    3       5         2        1     3
# GAMBLING                              0       0         0        0     0
# INTERFERENCE WITH PUBLIC OFFICER      0       0         0        0     0
# MOTOR VEHICLE THEFT                   0       1         0        0     0
# NARCOTICS                             1       0         0        0     0
# ...

# %%
(crimes
  .sample(500)
  .assign(month_name=lambda df:pd.to_datetime(df['Date']).dt.month_name()
  .astype('category')
  .cat.reorder_categories(['January','February','March','April','May','June',
                           'July','August','September','October','November','December'],ordered=True))
  .pipe(lambda df:pd.crosstab(index=df['Primary Type'],columns=df.month_name))
)
# Out:
# month_name                        January  February  March  April  May  June  \
# Primary Type
# ARSON                                   0         0      0      0    1     0
# ASSAULT                                 0         0      0      0    0     0
# BATTERY                                 0         1      1      0    1     0
# BURGLARY                                1         0      0      0    0     1
# CRIM SEXUAL ASSAULT                     0         0      1      1    0     0
# CRIMINAL DAMAGE                         0         0      0      0    0     1
# CRIMINAL TRESPASS                       0         0      0      0    1     0
# DECEPTIVE PRACTICE                      2         1      0      1    1     2
# INTERFERENCE WITH PUBLIC OFFICER        0         0      1      0    0     0
# INTIMIDATION                            0         0      0      0    0     0
# MOTOR VEHICLE THEFT                     0         0      0      0    0     0
# ...
