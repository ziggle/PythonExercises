# %% [markdown]
# https://betterdatascience.com/style-pandas-dataframes/
# https://stackoverflow.com/questions/67869034/styler-object-has-no-attribute-style

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

df = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, np.nan],[19, 439, 6, 452, 226,232]],
                  index=pd.Index(['Tumour (Positive)', 'Non-Tumour (Negative)'], name='Actual Label:'),
                  columns=pd.MultiIndex.from_product([['Decision Tree', 'Regression', 'Random'],['Tumour', 'Non-Tumour']], names=['Model:', 'Predicted:']))
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_781f3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_781f3_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_781f3_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_781f3_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_781f3_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_781f3_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_781f3_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_781f3_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_781f3_level1_col4" class="col_heading level1 col4" >Tumour</th>
#       <th id="T_781f3_level1_col5" class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_781f3_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_781f3_row0_col0" class="data row0 col0" >38.000000</td>
#       <td id="T_781f3_row0_col1" class="data row0 col1" >2.000000</td>
#       <td id="T_781f3_row0_col2" class="data row0 col2" >18.000000</td>
#       <td id="T_781f3_row0_col3" class="data row0 col3" >22.000000</td>
#       <td id="T_781f3_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_781f3_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_781f3_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_781f3_row1_col0" class="data row1 col0" >19.000000</td>
#       <td id="T_781f3_row1_col1" class="data row1 col1" >439.000000</td>
#       <td id="T_781f3_row1_col2" class="data row1 col2" >6.000000</td>
#       <td id="T_781f3_row1_col3" class="data row1 col3" >452.000000</td>
#       <td id="T_781f3_row1_col4" class="data row1 col4" >226</td>
#       <td id="T_781f3_row1_col5" class="data row1 col5" >232.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
def format_color_groups(values):
    if values =='Y':
        return  'color:red;border-collapse: collapse; border: 1px solid black;'
    elif values  == 'N':
        return  'color:green;border-collapse: collapse; border: 1px solid black;'
    else:
        return  'border-collapse: collapse; border: 1px solid black;'

df = df.style.applymap(format_color_groups)
#now df is styler so no need to add style
df = df.set_table_attributes('style="border-collapse: collapse; border: 12px solid black;"')
df
# Out:
# <style type="text/css">
# #T_994cd_row0_col0, #T_994cd_row0_col1, #T_994cd_row0_col2, #T_994cd_row0_col3, #T_994cd_row0_col4, #T_994cd_row0_col5, #T_994cd_row1_col0, #T_994cd_row1_col1, #T_994cd_row1_col2, #T_994cd_row1_col3, #T_994cd_row1_col4, #T_994cd_row1_col5 {
#   border-collapse: collapse;
#   border: 1px solid black;
# }
# </style>
# <table id="T_994cd" style="border-collapse: collapse; border: 12px solid black;">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_994cd_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_994cd_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_994cd_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_994cd_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_994cd_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_994cd_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_994cd_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_994cd_level1_col4" class="col_heading level1 col4" >Tumour</th>
#       <th id="T_994cd_level1_col5" class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_994cd_level0_row0" class="row_heading level0 row0" >Tumour (Positive)</th>
#       <td id="T_994cd_row0_col0" class="data row0 col0" >38.000000</td>
#       <td id="T_994cd_row0_col1" class="data row0 col1" >2.000000</td>
#       <td id="T_994cd_row0_col2" class="data row0 col2" >18.000000</td>
#       <td id="T_994cd_row0_col3" class="data row0 col3" >22.000000</td>
#       <td id="T_994cd_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_994cd_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_994cd_level0_row1" class="row_heading level0 row1" >Non-Tumour (Negative)</th>
#       <td id="T_994cd_row1_col0" class="data row1 col0" >19.000000</td>
#       <td id="T_994cd_row1_col1" class="data row1 col1" >439.000000</td>
#       <td id="T_994cd_row1_col2" class="data row1 col2" >6.000000</td>
#       <td id="T_994cd_row1_col3" class="data row1 col3" >452.000000</td>
#       <td id="T_994cd_row1_col4" class="data row1 col4" >226</td>
#       <td id="T_994cd_row1_col5" class="data row1 col5" >232.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2021-01-01", periods=10),
                          columns=["Tokyo", "Beijing"])

def rain_condition(v):
    if v < 1.75:
        return "Dry"
    elif v < 2.75:
        return "Rain"
    return "Heavy Rain"

def make_pretty(styler):
    styler.set_caption("Weather Conditions")
    styler.format(rain_condition)
    styler.format_index(lambda v: v.strftime("%a"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
    return styler

weather_df.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_e0113_row0_col0 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_e0113_row0_col1 {
#   background-color: #39adc3;
#   color: #f1f1f1;
# }
# #T_e0113_row1_col0 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_e0113_row1_col1 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_e0113_row2_col0 {
#   background-color: #abdeb7;
#   color: #000000;
# }
# #T_e0113_row2_col1 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_e0113_row3_col0, #T_e0113_row6_col1 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_e0113_row3_col1 {
#   background-color: #12256d;
#   color: #f1f1f1;
# }
# #T_e0113_row4_col0 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_e0113_row4_col1 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_e0113_row5_col0 {
#   background-color: #2258a5;
#   color: #f1f1f1;
# }
# #T_e0113_row5_col1 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_e0113_row6_col0 {
#   background-color: #7ecdbb;
#   color: #000000;
# }
# #T_e0113_row7_col0, #T_e0113_row7_col1, #T_e0113_row9_col0, #T_e0113_row9_col1 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_e0113_row8_col0 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
# }
# #T_e0113_row8_col1 {
#   background-color: #35aac3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e0113">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0113_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_e0113_level0_col1" class="col_heading level0 col1" >Beijing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0113_level0_row0" class="row_heading level0 row0" >Fri</th>
#       <td id="T_e0113_row0_col0" class="data row0 col0" >Rain</td>
#       <td id="T_e0113_row0_col1" class="data row0 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_e0113_level0_row1" class="row_heading level0 row1" >Sat</th>
#       <td id="T_e0113_row1_col0" class="data row1 col0" >Heavy Rain</td>
#       <td id="T_e0113_row1_col1" class="data row1 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_e0113_level0_row2" class="row_heading level0 row2" >Sun</th>
#       <td id="T_e0113_row2_col0" class="data row2 col0" >Rain</td>
#       <td id="T_e0113_row2_col1" class="data row2 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_e0113_level0_row3" class="row_heading level0 row3" >Mon</th>
#       <td id="T_e0113_row3_col0" class="data row3 col0" >Rain</td>
#       <td id="T_e0113_row3_col1" class="data row3 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_e0113_level0_row4" class="row_heading level0 row4" >Tue</th>
#       <td id="T_e0113_row4_col0" class="data row4 col0" >Heavy Rain</td>
#       <td id="T_e0113_row4_col1" class="data row4 col1" >Rain</td>
#     </tr>
#     <tr>
#       <th id="T_e0113_level0_row5" class="row_heading level0 row5" >Wed</th>
#       <td id="T_e0113_row5_col0" class="data row5 col0" >Heavy Rain</td>
#       <td id="T_e0113_row5_col1" class="data row5 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_e0113_level0_row6" class="row_heading level0 row6" >Thu</th>
#       <td id="T_e0113_row6_col0" class="data row6 col0" >Rain</td>
#       <td id="T_e0113_row6_col1" class="data row6 col1" >Rain</td>
#     </tr>
#     <tr>
#       <th id="T_e0113_level0_row7" class="row_heading level0 row7" >Fri</th>
#       <td id="T_e0113_row7_col0" class="data row7 col0" >Dry</td>
#       <td id="T_e0113_row7_col1" class="data row7 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_e0113_level0_row8" class="row_heading level0 row8" >Sat</th>
#       <td id="T_e0113_row8_col0" class="data row8 col0" >Heavy Rain</td>
#       <td id="T_e0113_row8_col1" class="data row8 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_e0113_level0_row9" class="row_heading level0 row9" >Sun</th>
#       <td id="T_e0113_row9_col0" class="data row9 col0" >Dry</td>
#       <td id="T_e0113_row9_col1" class="data row9 col1" >Dry</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df.loc["2021-01-04":"2021-01-08"].style.pipe(make_pretty)
# Out:
# <style  type="text/css" >
# #T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow0_col0{
#             background-color:  #75c9bd;
#             color:  #000000;
#         }#T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow0_col1{
#             background-color:  #2073b2;
#             color:  #f1f1f1;
#         }#T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow1_col0{
#             background-color:  #234c9f;
#             color:  #f1f1f1;
#         }#T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow1_col1{
#             background-color:  #24409a;
#             color:  #f1f1f1;
#         }#T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow2_col0{
#             background-color:  #cfecb3;
#             color:  #000000;
#         }#T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow2_col1{
#             background-color:  #32a6c2;
#             color:  #000000;
#         }#T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow3_col0{
#             background-color:  #ffffd9;
#             color:  #000000;
#         }#T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow3_col1{
#             background-color:  #daf0b3;
#             color:  #000000;
#         }#T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow4_col0{
#             background-color:  #f3fabf;
#             color:  #000000;
#         }#T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow4_col1{
#             background-color:  #1f7eb7;
#             color:  #000000;
#         }</style><table id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47e" ><caption>Weather Conditions</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Tokyo</th>        <th class="col_heading level0 col1" >Beijing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47elevel0_row0" class="row_heading level0 row0" >2021-01-04 00:00:00</th>
#                         <td id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow0_col0" class="data row0 col0" >Rain</td>
#                         <td id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow0_col1" class="data row0 col1" >Heavy Rain</td>
#             </tr>
#             <tr>
#                         <th id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47elevel0_row1" class="row_heading level0 row1" >2021-01-05 00:00:00</th>
#                         <td id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow1_col0" class="data row1 col0" >Heavy Rain</td>
#                         <td id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow1_col1" class="data row1 col1" >Heavy Rain</td>
#             </tr>
#             <tr>
#                         <th id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47elevel0_row2" class="row_heading level0 row2" >2021-01-06 00:00:00</th>
#                         <td id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow2_col0" class="data row2 col0" >Rain</td>
#                         <td id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow2_col1" class="data row2 col1" >Heavy Rain</td>
#             </tr>
#             <tr>
#                         <th id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47elevel0_row3" class="row_heading level0 row3" >2021-01-07 00:00:00</th>
#                         <td id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow3_col0" class="data row3 col0" >Dry</td>
#                         <td id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow3_col1" class="data row3 col1" >Rain</td>
#             </tr>
#             <tr>
#                         <th id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47elevel0_row4" class="row_heading level0 row4" >2021-01-08 00:00:00</th>
#                         <td id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow4_col0" class="data row4 col0" >Dry</td>
#                         <td id="T_7c09479c_ccd9_11ed_b9bd_cc3d827df47erow4_col1" class="data row4 col1" >Heavy Rain</td>
#             </tr>
#     </tbody></table>

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({
    "A": [0, -5, 12, -4, 3],
    "B": [12.24, 3.14, 2.71, -3.14, np.nan],
    "C": [0.5, 1.2, 0.3, 1.9, 2.2],
    "D": [2000, np.nan, 1000, 7000, 5000]
})
df
# Out:
#     A      B    C       D
# 0   0  12.24  0.5  2000.0
# 1  -5   3.14  1.2     NaN
# 2  12   2.71  0.3  1000.0
# 3  -4  -3.14  1.9  7000.0
# 4   3    NaN  2.2  5000.0

# %%
df.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e0885">
#   <thead>
#     <tr>
#       <th id="T_e0885_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e0885_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_e0885_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_e0885_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e0885_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_e0885_row0_col1" class="data row0 col1" >12.240000</td>
#       <td id="T_e0885_row0_col2" class="data row0 col2" >0.500000</td>
#       <td id="T_e0885_row0_col3" class="data row0 col3" >2000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_e0885_row1_col0" class="data row1 col0" >-5</td>
#       <td id="T_e0885_row1_col1" class="data row1 col1" >3.140000</td>
#       <td id="T_e0885_row1_col2" class="data row1 col2" >1.200000</td>
#       <td id="T_e0885_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_e0885_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_e0885_row2_col1" class="data row2 col1" >2.710000</td>
#       <td id="T_e0885_row2_col2" class="data row2 col2" >0.300000</td>
#       <td id="T_e0885_row2_col3" class="data row2 col3" >1000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_e0885_row3_col0" class="data row3 col0" >-4</td>
#       <td id="T_e0885_row3_col1" class="data row3 col1" >-3.140000</td>
#       <td id="T_e0885_row3_col2" class="data row3 col2" >1.900000</td>
#       <td id="T_e0885_row3_col3" class="data row3 col3" >7000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_e0885_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_e0885_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_e0885_row4_col2" class="data row4 col2" >2.200000</td>
#       <td id="T_e0885_row4_col3" class="data row4 col3" >5000.000000</td>
#     </tr>
#   </tbody>
# </table>
