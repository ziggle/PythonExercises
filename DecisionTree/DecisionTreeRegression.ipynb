# %% [markdown]
# https://medium.com/@HalderNilimesh/delving-into-non-linear-regression-with-decision-trees-in-python-an-in-depth-coding-tutorial-8cb41fca122a

# %%
# importing required libraries 
# importing Scikit-learn library and datasets package
from sklearn import datasets  
import pandas as pd
# Loading the iris plants dataset (classification)
df=pd.read_csv("iris.csv")
print(df.head())
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
X = df.drop('variety', axis=1)

df['variety']= pd.Categorical(df['variety'])
df['variety'] = df.variety.cat.codes
y = df['variety']
model = DecisionTreeRegressor()
model.fit(X, y)
# Out:
# DecisionTreeRegressor()

# %%
predictions = model.predict(X)

# %%
from sklearn import tree

tree.plot_tree(model)
# Out:
# [Text(167.4, 199.32, 'X[2] <= 2.45\nmse = 0.667\nsamples = 150\nvalue = 1.0'),
#  Text(141.64615384615385, 163.07999999999998, 'mse = 0.0\nsamples = 50\nvalue = 0.0'),
#  Text(193.15384615384616, 163.07999999999998, 'X[3] <= 1.75\nmse = 0.25\nsamples = 100\nvalue = 1.5'),
#  Text(103.01538461538462, 126.83999999999999, 'X[2] <= 4.95\nmse = 0.084\nsamples = 54\nvalue = 1.093'),
#  Text(51.50769230769231, 90.6, 'X[3] <= 1.65\nmse = 0.02\nsamples = 48\nvalue = 1.021'),
#  Text(25.753846153846155, 54.359999999999985, 'mse = 0.0\nsamples = 47\nvalue = 1.0'),
#  Text(77.26153846153846, 54.359999999999985, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(154.52307692307693, 90.6, 'X[3] <= 1.55\nmse = 0.222\nsamples = 6\nvalue = 1.667'),
#  Text(128.76923076923077, 54.359999999999985, 'mse = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(180.27692307692308, 54.359999999999985, 'X[0] <= 6.95\nmse = 0.222\nsamples = 3\nvalue = 1.333'),
# ...

# %%
model = DecisionTreeRegressor(max_depth = 4)
model.fit(X, y)
tree.plot_tree(model)
# Out:
# [Text(167.4, 195.696, 'X[3] <= 0.8\nmse = 0.667\nsamples = 150\nvalue = 1.0'),
#  Text(141.64615384615385, 152.208, 'mse = 0.0\nsamples = 50\nvalue = 0.0'),
#  Text(193.15384615384616, 152.208, 'X[3] <= 1.75\nmse = 0.25\nsamples = 100\nvalue = 1.5'),
#  Text(103.01538461538462, 108.72, 'X[2] <= 4.95\nmse = 0.084\nsamples = 54\nvalue = 1.093'),
#  Text(51.50769230769231, 65.232, 'X[3] <= 1.65\nmse = 0.02\nsamples = 48\nvalue = 1.021'),
#  Text(25.753846153846155, 21.744, 'mse = 0.0\nsamples = 47\nvalue = 1.0'),
#  Text(77.26153846153846, 21.744, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(154.52307692307693, 65.232, 'X[3] <= 1.55\nmse = 0.222\nsamples = 6\nvalue = 1.667'),
#  Text(128.76923076923077, 21.744, 'mse = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(180.27692307692308, 21.744, 'mse = 0.222\nsamples = 3\nvalue = 1.333'),
#  Text(283.2923076923077, 108.72, 'X[2] <= 4.85\nmse = 0.021\nsamples = 46\nvalue = 1.978'),
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

MAE = mean_absolute_error(y, predictions)
MSE = mean_squared_error(y, predictions)

print(MAE,MSE)
# Out:
# 0.0 0.0
