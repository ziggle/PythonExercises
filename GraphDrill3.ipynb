# %% [markdown]
# https://medium.com/@krishnakaturi9999/introduction-13d62b38682f

# %%
import os
os.path.abspath("")
# Out:
# 'C:\\Users\\Mark\\Dropbox\\GitHub\\PythonExercises'

# %%
import pandas as pd
df=pd.read_csv("car data.csv")
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type
# 0     ritz  2014           3.35           5.59       27000    Petrol  \
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df['Present_Price'].plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
df['Present_Price'].plot.box()
# Out:
# <AxesSubplot: >

# %%
df['Present_Price'].plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df['Present_Price'].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df['Present_Price'].plot(kind='line')
# Out:
# <AxesSubplot: >

# %%
df['Present_Price'].plot.line()
# Out:
# <AxesSubplot: >

# %%
df['Fuel_Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Fuel_Type'>

# %%
df['Fuel_Type'].value_counts().plot.bar()
# Out:
# <AxesSubplot: xlabel='Fuel_Type'>

# %%
df.plot(kind='scatter', x='Selling_Price', y='Present_Price')
# Out:
# <AxesSubplot: xlabel='Selling_Price', ylabel='Present_Price'>

# %%
df.plot.scatter(x='Selling_Price', y='Present_Price')
# Out:
# <AxesSubplot: xlabel='Selling_Price', ylabel='Present_Price'>

# %%
df.boxplot(by='Fuel_Type', column='Selling_Price',figsize=(6,6))
# Out:
# <AxesSubplot: title={'center': 'Selling_Price'}, xlabel='Fuel_Type'>

# %%
df.plot.box(by='Fuel_Type', column='Selling_Price',figsize=(6,6))
# Out:
# Selling_Price    AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %%
df_cross = pd.crosstab(df['Seller_Type'], df['Fuel_Type'])
df_cross.plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Seller_Type'>
