# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats
import sklearn.linear_model
url="vehicles.csv.zip"
df = pd.read_csv(url)
df.head()
# Out:
# C:\Users\Mark\AppData\Local\Temp\ipykernel_12892\1687522911.py:7: DtypeWarning: Columns (68,70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...

# %%
# Create a probability plot

df2 =(df
      [['city08']]
      .sort_values(by='city08')
      .assign(
      quantiles=lambda df_:np.sort(np.random.normal(size=len(df))),
      )
)

# %%
ax = (df2
     .plot.scatter(x='quantiles',y='city08',title='Probability Plot')
     )
lm=sklearn.linear_model.LinearRegression()
lm.fit(df2[['quantiles']],df2['city08'])

x = np.arange(-4,5)
plt.plot(x,lm.coef_*x+lm.intercept_,c='r')
