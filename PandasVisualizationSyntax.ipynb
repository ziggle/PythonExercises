# %% [markdown]
# https://medium.com/@shouke.wei/easy-and-simple-syntax-of-pandas-for-data-visualization-c213e232ec46

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/shoukewei/data/main/data-pydm/gdp_top_six_economies.csv'
df = pd.read_csv(url,index_col='Year') 
df.head()
# Out:
#              China       Germany         India         Japan  United Kingdom
# Year
# 1991  3.833733e+11  1.868945e+12  2.701053e+11  3.584420e+12    1.142797e+12  \
# 1992  4.269157e+11  2.131572e+12  2.882084e+11  3.908809e+12    1.179660e+12
# 1993  4.447313e+11  2.071324e+12  2.792960e+11  4.454144e+12    1.061389e+12
# 1994  5.643247e+11  2.205074e+12  3.272756e+11  4.998798e+12    1.140490e+12
# 1995  7.345479e+11  2.585792e+12  3.602820e+11  5.545564e+12    1.346423e+12
#
#       United States
# Year
# 1991   6.158129e+12
# 1992   6.520327e+12
# 1993   6.858559e+12
# 1994   7.287236e+12
# 1995   7.639749e+12

# %%
df.columns
# Out:
# Index(['China', 'Germany', 'India', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df.plot.line()
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
df.plot.line(y=['United States','China','Japan','Germany'], 
             title='GDP of world top 4 economies', 
             ylabel='GDP (current US$)',
             figsize=(8,4))
# Out:
# <AxesSubplot: title={'center': 'GDP of world top 4 economies'}, xlabel='Year', ylabel='GDP (current US$)'>

# %%
axes = df.plot.line(subplots=True, 
                    y=['United States','China','Japan','Germany'], 
                    title='GDP of world top 4 economies', 
                    ylabel='GDP (current US$)',
                    figsize=(10, 8))

# %%
axes = df.plot.line(subplots=True, 
                    y=['United States','China','Japan','Germany'], 
                    title='GDP of world top 4 economies', 
                    ylabel='GDP (current US$)',
                    figsize=(10, 8),
                    layout=(2,2))

# %%
gdp_mean = df.agg('mean')
gdp_mean
# Out:
# China             5.070277e+12
# Germany           2.941571e+12
# India             1.199736e+12
# Japan             4.864806e+12
# United Kingdom    2.206106e+12
# United States     1.320973e+13
# dtype: float64

# %%
gdp_mean.plot.bar(figsize=(8,4),
                  xlabel='Multi-anual average GDP',
                  ylabel='GDP (current US$)')
# Out:
# <AxesSubplot: xlabel='Multi-anual average GDP', ylabel='GDP (current US$)'>

# %%
df_3y = df[-3:]
df_3y
df_3y.plot.bar(figsize=(8,4),
               xlabel='Recent 3 years',
               ylabel='GDP (current US$)')
# Out:
# <AxesSubplot: xlabel='Recent 3 years', ylabel='GDP (current US$)'>

# %%
df_3y.plot.barh(figsize=(8,5),
                xlabel='Recent 3 years',
                ylabel='GDP (current US$)'
                )
# Out:
# <AxesSubplot: xlabel='Recent 3 years', ylabel='GDP (current US$)'>

# %%
df_3y.plot.bar(stacked=True,
               figsize=(8,4),
               xlabel='Recent 3 years',
               ylabel='GDP (current US$)'
               )
# Out:
# <AxesSubplot: xlabel='Recent 3 years', ylabel='GDP (current US$)'>

# %%
df['United States'].plot.hist(
    bins=25,
    figsize=(8,4))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df[['United States', 'China']].plot.hist(
    bins=25,
    alpha=0.6, 
    figsize=(8,4))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df[['United States', 'China']].plot.hist(
    bins=25, 
    alpha=0.6,                              
    stacked=True,
    figsize=(8,4))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.plot.box(figsize=(8,4),
            rot=45)
# Out:
# <AxesSubplot: >

# %%
color = {
    "boxes": "DarkGreen",
    "whiskers": "DarkOrange",
    "medians": "DarkBlue",
    "caps": "Gray",
}

df.plot.box(color=color, 
            sym="r+",
            vert=False,
            figsize=(8,6))
# Out:
# <AxesSubplot: >

# %%
df.plot.area(figsize=(8,4),
            ylabel='GDP (current US$)')
# Out:
# <AxesSubplot: xlabel='Year', ylabel='GDP (current US$)'>

# %%
df.plot.area(figsize=(8,4),
            ylabel='GDP (current US$)', stacked=False)
# Out:
# <AxesSubplot: xlabel='Year', ylabel='GDP (current US$)'>

# %%
df_3y.index=['2018', '2019', '2020']
pie = df_3y.plot.pie(y='United States',  
                     legend=True,
                     autopct='%.2f',
                     rotatelabels=45)
pie.legend(loc='upper left')

# %%
df.plot.scatter(x='China',
                y='United States',  
                figsize=(8,4),  
                color='Green')
# Out:
# <AxesSubplot: xlabel='China', ylabel='United States'>

# %%
import matplotlib.cm
cmap = matplotlib.cm.get_cmap('Reds')
df.plot.hexbin(x='China', 
               y='United States', 
               figsize=(8,4))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 3
#       1 import matplotlib.cm
#       2 cmap = matplotlib.cm.get_cmap('Reds')
# ----> 3 df.plot.hexbin(x='China',
#       4                y='United States',
#       5                figsize=(8,4))
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:1765, in PlotAccessor.hexbin(self, x, y, C, reduce_C_function, gridsize, **kwargs)
#    1762 if gridsize is not None:
#    1763     kwargs["gridsize"] = gridsize
# -> 1765 return self(kind="hexbin", x=x, y=y, C=C, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:920, in PlotAccessor.__call__(self, *args, **kwargs)
#     918 if kind in self._dataframe_kinds:
#     919     if isinstance(data, ABCDataFrame):
# --> 920         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     921     else:
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 10000
df = pd.DataFrame({'x': np.random.randn(n),
                   'y': np.random.randn(n)})
ax = df.plot.hexbin(x='x', y='y', gridsize=20)

# %%
df.plot.kde(figsize=(8,4))

# %%
df.plot.kde(figsize=(8,4), 
            bw_method=0.1)
