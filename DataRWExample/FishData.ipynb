# %%
import pandas as pd

url="https://www.dnr.state.mn.us/lakefind/showreport.html?downum=31045400"

from urllib.request import Request, urlopen

req = Request(
    url=url, 
    headers={'User-Agent': 'Mozilla/5.0'}
)
webpage = urlopen(req).read()

# %%
with open("test.html","r") as f:
    x=f.read()

print(x)
# Out:
# <!DOCTYPE html><!-- Rendered HTML has been minified --><html data-org="MN_DNR" lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# schema: http://schema.org/ sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema# "><head><script type="application/ld+json">{ "@context": "https://schema.org", "@type": "GovernmentOrganization", "name": "Minnesota DNR - MN Department of Natural Resources", "url": "https://www.dnr.state.mn.us/", "logo": "https://www.dnr.state.mn.us/themes/mndnr/images/mndnr_logo.png","description": "The mission of the Minnesota Department of Natural Resources (DNR) is to work with citizens to conserve and manage the state's natural resources, to provide outdoor recreation opportunities, and to provide for commercial uses of natu
# ...

# %%
import pandas as pd

df = pd.read_html(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_html(x)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1208 check_dtype_backend(dtype_backend)
#    1210 io = stringify_path(io)
# -> 1212 return _parse(
#    1213     flavor=flavor,
#    1214     io=io,
#    1215     match=match,
#    1216     header=header,
#    1217     index_col=index_col,
#    1218     skiprows=skiprows,
#    1219     parse_dates=parse_dates,
#    1220     thousands=thousands,
#    1221     attrs=attrs,
# ...
