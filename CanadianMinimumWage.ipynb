# %% [markdown]
# https://medium.com/analytics-vidhya/draw-a-unique-barplot-using-matplotlib-in-python-f6b88b4a6f89

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Mydict={
 'Province':['Alberta','British Columbia','Manitoba','New Brunswick','Newfoundland & Labrador',
 'Northwest Territories','Nova Scotia','Nunavut','Ontario','Prince Edward Island',
 'Quebec','Saskatchewan','Yukon'],
 'Province_Code':['AB','BC','MB','NB','NL','NT','NS','NU','ON','PE','QC','SK','YT'],
 'Minimum_Wage':['15.00','14.60','11.65','11.70','11.65','13.46','12.55','13.00','14.00','12.85','13.10','11.32','13.71']
}
df=pd.DataFrame(Mydict)
#change the datatype of minimum wage from object to float
df['Minimum_Wage'] = df['Minimum_Wage'].astype(str).astype(float)
print(df.dtypes)
print(df)
# Out:
# Province          object
# Province_Code     object
# Minimum_Wage     float64
# dtype: object
#                    Province Province_Code  Minimum_Wage
# 0                   Alberta            AB         15.00
# 1          British Columbia            BC         14.60
# 2                  Manitoba            MB         11.65
# 3             New Brunswick            NB         11.70
# 4   Newfoundland & Labrador            NL         11.65
# 5     Northwest Territories            NT         13.46
# 6               Nova Scotia            NS         12.55
# 7                   Nunavut            NU         13.00
# 8                   Ontario            ON         14.00
# 9      Prince Edward Island            PE         12.85
# 10                   Quebec            QC         13.10
# 11             Saskatchewan            SK         11.32
# 12                    Yukon            YT         13.71

# %%
fig,ax = plt.subplots(figsize=(9,6))
sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax)
ax.set_title('Minimum Wage Comparison across Canada')
# Out:
# C:\Users\mbieg\AppData\Local\Temp\ipykernel_35524\4204442874.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax)
# Text(0.5, 1.0, 'Minimum Wage Comparison across Canada')

# %%
fig,ax = plt.subplots(figsize=(9,6))
sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax)
ax.set_title('Minimum Wage Comparison across Canada')
 
# set the font size of labels into 16 and remove the tick line
ax.tick_params(labelsize=16,length=0)
# Out:
# C:\Users\mbieg\AppData\Local\Temp\ipykernel_35524\2924382543.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax)

# %%
fig,ax = plt.subplots(figsize=(9,6))
sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax)
ax.set_title('Minimum Wage Comparison across Canada')
 
# set the font size of labels into 16 and remove the tick line
ax.tick_params(labelsize=16,length=0)
# Out:
# C:\Users\mbieg\AppData\Local\Temp\ipykernel_35524\2924382543.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax)

# %%
# method 1
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
#method 2
plt.box(False)

# %%
fig,ax = plt.subplots(figsize=(9,6))
sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax)
ax.set_title('Minimum Wage Comparison across Canada')
 
# set the font size of labels into 16 and remove the tick line
ax.tick_params(labelsize=16,length=0)
plt.box(False)
# Out:
# C:\Users\mbieg\AppData\Local\Temp\ipykernel_35524\3328463704.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax)

# %%
fig,ax = plt.subplots(figsize=(9,6))
sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax,
 order = df.sort_values('Minimum_Wage').Province_Code) #reorder bars   ) #change the color of bars
ax.set_title('Minimum Wage Comparison across Canada')
 
 
# set the font size of labels into 16 and remove the tick line
ax.tick_params(labelsize=16,length=0)
plt.box(False) #removing border lines
# Out:
# C:\Users\mbieg\AppData\Local\Temp\ipykernel_35524\4086862263.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax,

# %%
fig,ax = plt.subplots(figsize=(9,6))
sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax,
 order = df.sort_values('Minimum_Wage').Province_Code, palette = 'plasma')
ax.set_title('Minimum Wage Comparison across Canada')
ax.tick_params(labelsize=16,length=0)
plt.box(False)
# Out:
# C:\Users\mbieg\AppData\Local\Temp\ipykernel_35524\3465130596.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax,

# %%
fig,ax = plt.subplots(figsize=(9,6))
sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax,
 order = df.sort_values('Minimum_Wage').Province_Code, palette = 'plasma')
ax.set_title('Minimum Wage Comparison across Canada')
ax.tick_params(labelsize=16,length=0)
plt.box(False)
# add grid lines for y axis
ax.yaxis.grid(linewidth=0.5,color='black')
# put the grid lines below bars
ax.set_axisbelow(True)
# Out:
# C:\Users\mbieg\AppData\Local\Temp\ipykernel_35524\3243127264.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax,

# %%
fig,ax = plt.subplots(figsize=(12,8))
sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax,
 order = df.sort_values('Minimum_Wage').Province_Code, palette = 'plasma',alpha=0.8)
ax.set_title('Minimum Wage Comparison across Canada',backgroundcolor='#565656',
 fontsize=20, weight='bold',color='white',style='italic',loc='center',pad=30)
 
ax.tick_params(labelsize=16,length=0)
plt.box(False)
ax.yaxis.grid(linewidth=0.5,color='grey',linestyle='-.')
ax.set_axisbelow(True)
ax.set_xlabel('Province',weight='bold',size=15)
ax.set_ylabel('Minimum Wage',weight='bold',size=15)
plt.yticks(np.arange(0, 18, 4)) #yticks starts from 0 and ends at 18, step is 4
ax.set_yticklabels([' ','$4','$8','$12','$16'],color='#565656')
plt.xticks(rotation=30,color='#565656')
plt.show()
# Out:
# C:\Users\mbieg\AppData\Local\Temp\ipykernel_35524\439257002.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x='Province_Code',y='Minimum_Wage',data=df,ci=95,ax=ax,
