# %% [markdown]
# https://towardsdev.com/colors-of-python-visualization-matplotlib-colormap-a2350e973c6b

# %%
from matplotlib import cm

print(dir(cm))
# Out:
# ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'LUTSIZE', 'MutableMapping', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'ScalarMappable', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', '_DeprecatedCmapDictWrapper', '__builtin_cmaps', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_api', '_cmap_registry', '_gen_cmap_registry',
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

matplotlib.rcParams['figure.figsize']=(10,50)

gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))

nrows = len(dir(cm))
figh = 0.35 + 0.15 + (nrows + (nrows - 1) * 0.1) * 0.22
fig, axs = plt.subplots(nrows=nrows + 1, figsize=(6.4, figh))
fig.subplots_adjust(top=1 - 0.35 / figh, bottom=0.15 / figh, left=0.2, right=0.99)

for ax, name in zip(axs, dir(cm)):
    try:
        ax.imshow(gradient, aspect='auto', cmap=cm.get_cmap(name))
        ax.text(-0.01, 0.5, name, va='center', ha='right', fontsize=10, transform=ax.transAxes)
    except:
        pass
for ax in axs:
        ax.set_axis_off()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
plt.figure(dpi=150)

##ListedColormap
# Multiple colors
plt.subplot(1,4,1)
#plt.bar(range(5),range(1,6),color=plt.cm.Accent(range(5)))
#plt.bar(range(5),range(1,6),color=plt.cm.get_cmap('Accent')(range(5)))
plt.bar(range(5),range(1,6),color=plt.get_cmap('Accent')(range(5)))

# Single color
plt.subplot(1,4,2)
plt.bar(range(5),range(1,6),color=plt.cm.Accent(4))

##LinearSegmentedColormap
# Multiple colors
plt.subplot(1,4,3)
plt.bar(range(5),range(1,6),color=plt.get_cmap('Blues')(np.linspace(0, 1, 5)))

# Single color
plt.subplot(1,4,4)
plt.bar(range(5),range(1,6),color=plt.get_cmap('Blues')(3))
# Out:
# <BarContainer object of 5 artists>
