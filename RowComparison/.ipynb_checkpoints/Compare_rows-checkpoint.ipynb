# %% [markdown]
# https://medium.com/hacking-and-slacking/comparing-rows-between-two-pandas-dataframes-c3b174ff560e

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('Data/employees1.csv')
df2 = pd.read_csv('Data/employees2.csv')
display(df1)
display(df2)
# Out:
#     ID FIRST_NAME   LAST_NAME            EMAIL  GENDER  \
# 0  424     Regine  Aberkirder           ra@zip  Female
# 1  989      Jessa       Acome        ja@me.com  Female
# 2  318      Marci       Acres      ma@fkaf.com  Female
# 3  996     Olympe       Acutt  oa@kljfaljf.com  Female
# 4  516       Baxy    Adamides    ba@google.com    Male
# 5  743      Melba       Addey    ma@fajfkj.com  Female
# 6  207     Willie  Addionisio        wa@me.com    Male
# 7  764       Noby     Agutter      na@goog.com    Male
#
#                  DEPARTMENT
# 0                 Marketing
# 1      Business Development
# 2                 Marketing
# 3                   Support
# 4  Research and Development
# 5                Accounting
# 6                        HR
# 7                Accounting
#     ID FIRST_NAME   LAST_NAME            EMAIL  GENDER            DEPARTMENT
# 0  424     Regine  Aberkirder           ra@zip  Female             Marketing
# ...

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(df2,
                              indicator=True,
                              how='outer')
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

# %%
dataframe_difference(df1, df2)
# Out:
#     ID FIRST_NAME LAST_NAME           EMAIL GENDER                DEPARTMENT  \
# 4  516       Baxy  Adamides   ba@google.com   Male  Research and Development
# 8  999       Mark   Biegert  fkjf@kfajf.com   Male               Engineering
#
#        _merge
# 4   left_only
# 8  right_only

# %%
dataframe_difference(df1, df2,which='both')
# Out:
#     ID FIRST_NAME   LAST_NAME            EMAIL  GENDER            DEPARTMENT  \
# 0  424     Regine  Aberkirder           ra@zip  Female             Marketing
# 1  989      Jessa       Acome        ja@me.com  Female  Business Development
# 2  318      Marci       Acres      ma@fkaf.com  Female             Marketing
# 3  996     Olympe       Acutt  oa@kljfaljf.com  Female               Support
# 5  743      Melba       Addey    ma@fajfkj.com  Female            Accounting
# 6  207     Willie  Addionisio        wa@me.com    Male                    HR
# 7  764       Noby     Agutter      na@goog.com    Male            Accounting
#
#   _merge
# 0   both
# 1   both
# 2   both
# 3   both
# 5   both
# 6   both
# 7   both
