# %% [markdown]
# https://towardsdev.com/the-ultimate-guide-to-loc-and-iloc-in-python-pandas-8b9c07d8c248

# %%
import pandas as pd
df = pd.DataFrame([['Puerto Rico', 'Sean', 568,'Consumer','PR',"A"],
                   ['Puerto Rico', 'Carol', 3341, 'Consumer', 'PR',"B"],
                   ['United States', 'Mary', 2666, 'Corporate','CA',"C"],
                   ['France', 'Biff', 345, 'Consumer', "BO", "D"],
                   ['United States', 'Biff',123,  'Corporate', 'MN',"E"]],
                   columns=['Customer Country','Customer Fname', 'Customer Id', 'Customer Segment', 'Customer State',"Temp"]
                 )

# %%
display(df)
# Out:
#   Customer Country Customer Fname  Customer Id Customer Segment  \
# 0      Puerto Rico           Sean          568         Consumer
# 1      Puerto Rico          Carol         3341         Consumer
# 2    United States           Mary         2666        Corporate
# 3           France           Biff          345         Consumer
# 4    United States           Biff          123        Corporate
#
#   Customer State Temp
# 0             PR    A
# 1             PR    B
# 2             CA    C
# 3             BO    D
# 4             MN    E

# %%
# Column Selection
df.loc[:, 'Customer Country':'Customer State']
# Out:
#   Customer Country Customer Fname  Customer Id Customer Segment Customer State
# 0      Puerto Rico           Sean          568         Consumer             PR
# 1      Puerto Rico          Carol         3341         Consumer             PR
# 2    United States           Mary         2666        Corporate             CA
# 3           France           Biff          345         Consumer             BO
# 4    United States           Biff          123        Corporate             MN

# %%
# Using loc for label-based selection
df.loc[[0,1,2], 'Customer Country':'Customer State']
# Out:
#   Customer Country Customer Fname  Customer Id Customer Segment Customer State
# 0      Puerto Rico           Sean          568         Consumer             PR
# 1      Puerto Rico          Carol         3341         Consumer             PR
# 2    United States           Mary         2666        Corporate             CA

# %%
# Selecting rows by integer location
df.iloc[[0,1,2,3] , [3,4,]]
# Out:
#   Customer Segment Customer State
# 0         Consumer             PR
# 1         Consumer             PR
# 2        Corporate             CA
# 3         Consumer             BO

# %%
df.iloc[[0,1,2] , 3:5]
# Out:
#   Customer Segment Customer State
# 0         Consumer             PR
# 1         Consumer             PR
# 2        Corporate             CA

# %%
df.iloc[:, 2:5]
# Out:
#    Customer Id Customer Segment Customer State
# 0          568         Consumer             PR
# 1         3341         Consumer             PR
# 2         2666        Corporate             CA
# 3          345         Consumer             BO
# 4          123        Corporate             MN

# %%
# Column Selection

df.iloc[:, 3:8]  # Notice that no error was generated
# Out:
#   Customer Segment Customer State Temp
# 0         Consumer             PR    A
# 1         Consumer             PR    B
# 2        Corporate             CA    C
# 3         Consumer             BO    D
# 4        Corporate             MN    E

# %%
#Column Selection

display(df[['Customer Country']])
print(type(df[['Customer Country']]))
# Out:
#   Customer Country
# 0      Puerto Rico
# 1      Puerto Rico
# 2    United States
# 3           France
# 4    United States
# <class 'pandas.core.frame.DataFrame'>

# %%
df[['Customer Country', 'Customer State']]
# Out:
#   Customer Country Customer State
# 0      Puerto Rico             PR
# 1      Puerto Rico             PR
# 2    United States             CA
# 3           France             BO
# 4    United States             MN

# %%
condition = df['Customer Id'] > 600
df.loc[condition]
# Out:
#   Customer Country Customer Fname  Customer Id Customer Segment  \
# 1      Puerto Rico          Carol         3341         Consumer
# 2    United States           Mary         2666        Corporate
#
#   Customer State Temp
# 1             PR    B
# 2             CA    C

# %%
df.loc[df['Customer Id'] > 600]
# Out:
#   Customer Country Customer Fname  Customer Id Customer Segment  \
# 1      Puerto Rico          Carol         3341         Consumer
# 2    United States           Mary         2666        Corporate
#
#   Customer State Temp
# 1             PR    B
# 2             CA    C

# %%
# loc for filtering

df.loc[df['Customer Country'] == 'United States']
# Out:
#   Customer Country Customer Fname  Customer Id Customer Segment  \
# 2    United States           Mary         2666        Corporate
# 4    United States           Biff          123        Corporate
#
#   Customer State Temp
# 2             CA    C
# 4             MN    E

# %%
df.iloc[[0, 2, 4]]
# Out:
#   Customer Country Customer Fname  Customer Id Customer Segment  \
# 0      Puerto Rico           Sean          568         Consumer
# 2    United States           Mary         2666        Corporate
# 4    United States           Biff          123        Corporate
#
#   Customer State Temp
# 0             PR    A
# 2             CA    C
# 4             MN    E

# %%
df.iloc[:3, :2]
# Out:
#   Customer Country Customer Fname
# 0      Puerto Rico           Sean
# 1      Puerto Rico          Carol
# 2    United States           Mary

# %%
condition = df['Customer Id'] > 600
df[condition]
# Out:
#   Customer Country Customer Fname  Customer Id Customer Segment  \
# 1      Puerto Rico          Carol         3341         Consumer
# 2    United States           Mary         2666        Corporate
#
#   Customer State Temp
# 1             PR    B
# 2             CA    C

# %%
df[df['Customer Id'] > 600]
# Out:
#   Customer Country Customer Fname  Customer Id Customer Segment  \
# 1      Puerto Rico          Carol         3341         Consumer
# 2    United States           Mary         2666        Corporate
#
#   Customer State Temp
# 1             PR    B
# 2             CA    C

# %%
df[df['Customer Country'].isin(['United States', 'Puerto Rico'])]
# Out:
#   Customer Country Customer Fname  Customer Id Customer Segment  \
# 0      Puerto Rico           Sean          568         Consumer
# 1      Puerto Rico          Carol         3341         Consumer
# 2    United States           Mary         2666        Corporate
# 4    United States           Biff          123        Corporate
#
#   Customer State Temp
# 0             PR    A
# 1             PR    B
# 2             CA    C
# 4             MN    E

# %%
df[~df['Customer Country'].isin(['United States'])]
# Out:
#   Customer Country Customer Fname  Customer Id Customer Segment  \
# 0      Puerto Rico           Sean          568         Consumer
# 1      Puerto Rico          Carol         3341         Consumer
# 3           France           Biff          345         Consumer
#
#   Customer State Temp
# 0             PR    A
# 1             PR    B
# 3             BO    D

# %%
df.rename(columns={'Customer Id' : 'Customer_Id', "Customer Fname" : "Customer_Fname"}, inplace=True)
display(df)
# Out:
#   Customer Country Customer_Fname  Customer_Id Customer Segment  \
# 0      Puerto Rico           Sean          568         Consumer
# 1      Puerto Rico          Carol         3341         Consumer
# 2    United States           Mary         2666        Corporate
# 3           France           Biff          345         Consumer
# 4    United States           Biff          123        Corporate
#
#   Customer State Temp
# 0             PR    A
# 1             PR    B
# 2             CA    C
# 3             BO    D
# 4             MN    E

# %%
df.query('Customer_Id > 600')
# Out:
#   Customer Country Customer_Fname  Customer_Id Customer Segment  \
# 1      Puerto Rico          Carol         3341         Consumer
# 2    United States           Mary         2666        Corporate
#
#   Customer State Temp
# 1             PR    B
# 2             CA    C

# %%
df[df['Customer_Id'].between(600, 3000)]
# Out:
#   Customer Country Customer_Fname  Customer_Id Customer Segment  \
# 2    United States           Mary         2666        Corporate
#
#   Customer State Temp
# 2             CA    C

# %%
df[df['Customer Country'].str.startswith('Pu')]
# Out:
#   Customer Country Customer_Fname  Customer_Id Customer Segment  \
# 0      Puerto Rico           Sean          568         Consumer
# 1      Puerto Rico          Carol         3341         Consumer
#
#   Customer State Temp
# 0             PR    A
# 1             PR    B

# %%
df[df['Customer Country'].str.contains('Rico')]
# Out:
#   Customer Country Customer_Fname  Customer_Id Customer Segment  \
# 0      Puerto Rico           Sean          568         Consumer
# 1      Puerto Rico          Carol         3341         Consumer
#
#   Customer State Temp
# 0             PR    A
# 1             PR    B

# %%
df.loc[df['Customer Country'] == 'Puerto Rico', 'Customer Country'] = 'Jamaica'
display(df)
# Out:
#   Customer Country Customer_Fname  Customer_Id Customer Segment  \
# 0          Jamaica           Sean          568         Consumer
# 1          Jamaica          Carol         3341         Consumer
# 2    United States           Mary         2666        Corporate
# 3           France           Biff          345         Consumer
# 4    United States           Biff          123        Corporate
#
#   Customer State Temp
# 0             PR    A
# 1             PR    B
# 2             CA    C
# 3             BO    D
# 4             MN    E
