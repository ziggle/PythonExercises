# %% [markdown]
# https://levelup.gitconnected.com/20-pandas-functions-for-80-of-your-data-science-tasks-b610c8bfe63c

# %%
import pandas as pd
df = pd.read_csv('Popular_Baby_Names.csv')

# %%
df = pd.read_csv('Popular_Baby_Names.csv', sep=';', header=0, index_col=0, skiprows=5, na_values='N/A')
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [6,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Mia,79,5, 7,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Charlotte,59,6, 8,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Sarah,57,7, 9,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Isabella,56,8, 10,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Hannah,56,8, 11,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Grace,54,9, 12,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Angela,54,9, 13,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Ava,53,10, 14,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Joanna,49,11, 15,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Amelia,44,12, 16,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Evelyn,42,13, 17,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Ella,42,13, 18,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Arya,42,13, 19,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Ariana,40,14, 20,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Maya,39,15, 21,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Alina,39,15, 22,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Fiona,35,16, 23,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Fatima,34,17, 24,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Ashley,34,17, 25,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Anna,34,17, 26,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Anaya,34,17, 27,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Aria,33,18, 28,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Abigail,32,19, 29,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Victoria,32,19, 30,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Abby,31,20, 31,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Zoe,31,20, 32,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Ayesha,30,21, 33,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Vivian,30,21, 34,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Claire,30,21, 35,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Zoey,29,22, 36,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Audrey,29,22, 37,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Jessica,29,22, 38,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Sophie,28,23, 39,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Rachel,28,23, 40,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Alice,28,23, 41,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Zainab,28,23, 42,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Bella,27,24, 43,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Amy,27,24, 44,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Phoebe,27,24, 45,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Annie,26,25, 46,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Kayla,26,25, 47,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Zara,26,25, 48,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Maryam,26,25, 49,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Eva,26,25, 50,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Aisha,25,26, 51,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Tiffany,25,26, 52,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Ellie,25,26, 53,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Angelina,25,26, 54,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Katherine,24,27, 55,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Riley,24,27, 56,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Natalie,24,27, 57,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Avery,24,27, 58,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Jasmine,24,27, 59,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Alexandra,23,28, 60,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Aleena,23,28, 61,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Michelle,23,28, 62,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Hailey,23,28, 63,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Elena,23,28, 64,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Madison,23,28, 65,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Cynthia,23,28, 66,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Melody,22,29, 67,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Kaylee,21,30, 68,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Ivy,21,30, 69,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Chelsea,21,30, 70,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Elizabeth,21,30, 71,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Queenie,20,31, 72,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Sofia,20,31, 73,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Tenzin,20,31, 74,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Aizah,20,31, 75,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Irene,20,31, 76,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Allison,20,31, 77,2016,FEMALE,ASIAN AND PACIFIC ISLANDER,Isabel ...
#
# [19413 rows x 0 columns]

# %%
df = pd.read_csv('Popular_Baby_Names.csv')
df
# Out:
#          _id  Year of Birth  Gender                   Ethnicity  \
# 0          1           2016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 1          2           2016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 2          3           2016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 3          4           2016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 4          5           2016  FEMALE  ASIAN AND PACIFIC ISLANDER
# ...      ...            ...     ...                         ...
# 19413  19414           2011    MALE          WHITE NON HISPANIC
# 19414  19415           2011    MALE          WHITE NON HISPANIC
# 19415  19416           2011    MALE          WHITE NON HISPANIC
# 19416  19417           2011    MALE          WHITE NON HISPANIC
# 19417  19418           2011    MALE          WHITE NON HISPANIC
#
#       Child's First Name  Count  Rank
# 0                 Olivia    172     1
# 1                  Chloe    112     2
# 2                 Sophia    104     3
# 3                  Emily     99     4
# 4                   Emma     99     4
# ...                  ...    ...   ...
# 19413            STEPHEN     10    97
# 19414            STEPHEN     10    97
# 19415              DEREK     10    97
# 19416            BENNETT     10    97
# 19417              ELLIS     10    97
#
# [19418 rows x 7 columns]

# %%
df.describe()
# Out:
#                 _id  Year of Birth         Count          Rank
# count  19418.000000   19418.000000  19418.000000  19418.000000
# mean    9709.500000    2013.124318     33.520084     57.497116
# std     5605.638099       1.599749     38.243201     25.363693
# min        1.000000    2011.000000     10.000000      1.000000
# 25%     4855.250000    2012.000000     13.000000     38.000000
# 50%     9709.500000    2013.000000     20.000000     59.000000
# 75%    14563.750000    2014.000000     36.000000     78.000000
# max    19418.000000    2016.000000    426.000000    102.000000

# %%
df.describe(include='all')  # include all columns
# Out:
#                  _id  Year of Birth  Gender Ethnicity Child's First Name  \
# count   19418.000000   19418.000000   19418     19418              19418
# unique           NaN            NaN       2         7               3021
# top              NaN            NaN  FEMALE  HISPANIC              Avery
# freq             NaN            NaN    9933      5714                 38
# mean     9709.500000    2013.124318     NaN       NaN                NaN
# std      5605.638099       1.599749     NaN       NaN                NaN
# min         1.000000    2011.000000     NaN       NaN                NaN
# 25%      4855.250000    2012.000000     NaN       NaN                NaN
# 50%      9709.500000    2013.000000     NaN       NaN                NaN
# 75%     14563.750000    2014.000000     NaN       NaN                NaN
# max     19418.000000    2016.000000     NaN       NaN                NaN
#
#                Count          Rank
# count   19418.000000  19418.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean       33.520084     57.497116
# std        38.243201     25.363693
# min        10.000000      1.000000
# 25%        13.000000     38.000000
# 50%        20.000000     59.000000
# 75%        36.000000     78.000000
# max       426.000000    102.000000

# %%
df.describe(exclude='number') # exclude numerical columns
# Out:
#         Gender Ethnicity Child's First Name
# count    19418     19418              19418
# unique       2         7               3021
# top     FEMALE  HISPANIC              Avery
# freq      9933      5714                 38

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19418 entries, 0 to 19417
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _id                 19418 non-null  int64
#  1   Year of Birth       19418 non-null  int64
#  2   Gender              19418 non-null  object
#  3   Ethnicity           19418 non-null  object
#  4   Child's First Name  19418 non-null  object
#  5   Count               19418 non-null  int64
#  6   Rank                19418 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 1.0+ MB
# None

# %%
df['Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df['Gender'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='Gender'>

# %%
df['Count'].plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
# Select the first row
print(df.iloc[0])
# Out:
# _id                                            1
# Year of Birth                               2016
# Gender                                    FEMALE
# Ethnicity             ASIAN AND PACIFIC ISLANDER
# Child's First Name                        Olivia
# Count                                        172
# Rank                                           1
# Name: 0, dtype: object

# %%
# Select the first two rows
print(df.iloc[:2])
# Out:
#    _id  Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0    1           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 1    2           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
#
#    Count  Rank
# 0    172     1
# 1    112     2

# %%
# Select the first column
print(df.iloc[:, 0])
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 19413    19414
# 19414    19415
# 19415    19416
# 19416    19417
# 19417    19418
# Name: _id, Length: 19418, dtype: int64

# %%
# Select the first two columns
print(df.iloc[:, :2])
# Out:
#          _id  Year of Birth
# 0          1           2016
# 1          2           2016
# 2          3           2016
# 3          4           2016
# 4          5           2016
# ...      ...            ...
# 19413  19414           2011
# 19414  19415           2011
# 19415  19416           2011
# 19416  19417           2011
# 19417  19418           2011
#
# [19418 rows x 2 columns]

# %%
# Select the column name 'Gender'
print(df.loc[:,'Gender'])
# Out:
# 0        FEMALE
# 1        FEMALE
# 2        FEMALE
# 3        FEMALE
# 4        FEMALE
#           ...
# 19413      MALE
# 19414      MALE
# 19415      MALE
# 19416      MALE
# 19417      MALE
# Name: Gender, Length: 19418, dtype: object

# %%
df_new = df.assign(count_plus_5=df['Count'] + 5)
df_new.head()
# Out:
#    _id  Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0    1           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 1    2           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 2    3           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Sophia
# 3    4           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Emily
# 4    5           2016  FEMALE  ASIAN AND PACIFIC ISLANDER               Emma
#
#    Count  Rank  count_plus_5
# 0    172     1           177
# 1    112     2           117
# 2    104     3           109
# 3     99     4           104
# 4     99     4           104

# %%
df.isnull()
# Out:
#          _id  Year of Birth  Gender  Ethnicity  Child's First Name  Count  \
# 0      False          False   False      False               False  False
# 1      False          False   False      False               False  False
# 2      False          False   False      False               False  False
# 3      False          False   False      False               False  False
# 4      False          False   False      False               False  False
# ...      ...            ...     ...        ...                 ...    ...
# 19413  False          False   False      False               False  False
# 19414  False          False   False      False               False  False
# 19415  False          False   False      False               False  False
# 19416  False          False   False      False               False  False
# 19417  False          False   False      False               False  False
#
#         Rank
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 19413  False
# 19414  False
# 19415  False
# 19416  False
# 19417  False
#
# [19418 rows x 7 columns]

# %%
grouped = df.groupby('Gender')
# Print the mean of each group
print(grouped.mean())
# Out:
#                  _id  Year of Birth      Count       Rank
# Gender
# FEMALE   8871.121816    2013.122420  28.852008  52.362529
# MALE    10587.476858    2013.126305  38.408645  62.874222

# %%
# Transpose the DataFrame
df_transposed = df.transpose()

# Print the transposed DataFrame
df_transposed.head()
# Out:
#                                          0                           1      \
# _id                                          1                           2
# Year of Birth                             2016                        2016
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                      Olivia                       Chloe
#
#                                          2                           3      \
# _id                                          3                           4
# Year of Birth                             2016                        2016
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                      Sophia                       Emily
#
#                                          4                           5      \
# _id                                          5                           6
# Year of Birth                             2016                        2016
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                        Emma                         Mia
#
#                                          6                           7      \
# _id                                          7                           8
# Year of Birth                             2016                        2016
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                   Charlotte                       Sarah
#
#                                          8                           9      \
# _id                                          9                          10
# Year of Birth                             2016                        2016
# Gender                                  FEMALE                      FEMALE
# Ethnicity           ASIAN AND PACIFIC ISLANDER  ASIAN AND PACIFIC ISLANDER
# Child's First Name                    Isabella                      Hannah
#
#                     ...               19408               19409  \
# _id                 ...               19409               19410
# Year of Birth       ...                2011                2011
# Gender              ...                MALE                MALE
# Ethnicity           ...  WHITE NON HISPANIC  WHITE NON HISPANIC
# Child's First Name  ...               CADEN              CALVIN
#
#                                  19410               19411  \
# _id                              19411               19412
# Year of Birth                     2011                2011
# Gender                            MALE                MALE
# Ethnicity           WHITE NON HISPANIC  WHITE NON HISPANIC
# Child's First Name            AUGUSTUS               DEREK
#
#                                  19412               19413  \
# _id                              19413               19414
# Year of Birth                     2011                2011
# Gender                            MALE                MALE
# Ethnicity           WHITE NON HISPANIC  WHITE NON HISPANIC
# Child's First Name              BERISH             STEPHEN
#
#                                  19414               19415  \
# _id                              19415               19416
# Year of Birth                     2011                2011
# Gender                            MALE                MALE
# Ethnicity           WHITE NON HISPANIC  WHITE NON HISPANIC
# Child's First Name             STEPHEN               DEREK
#
#                                  19416               19417
# _id                              19417               19418
# Year of Birth                     2011                2011
# Gender                            MALE                MALE
# Ethnicity           WHITE NON HISPANIC  WHITE NON HISPANIC
# Child's First Name             BENNETT               ELLIS
#
# [5 rows x 19418 columns]

# %%
# Create the first DataFrame
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],
                   'value': [1, 2, 3, 4]})

# Create the second DataFrame
df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'],
                   'value': [5, 6, 7, 8]})

# Merge the two DataFrames on the 'key' column
merged_df = df1.merge(df2, on='key')

# Print the merged DataFrame
print(merged_df)
# Out:
#   key  value_x  value_y
# 0   B        2        5
# 1   D        4        6
