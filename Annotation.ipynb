# %% [markdown]
# https://towardsdev.com/how-to-add-text-and-annotate-to-a-visual-in-python-975356c0d42c

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(5,4),dpi=120)
plt.plot([1,2,5],[7,8,9])
plt.text(x=2.2,# x axis of the text
         y=8, # y axis of the text
         s='basic unility of text', #text
         rotation=1,# text rotation
         ha='left',
         va='baseline',
         # the font of text
         fontdict=dict(fontsize=12, color='r',
                       family='monospace',
                       weight='bold',
                      )
        )
# Out:
# C:\Users\mbieg\AppData\Local\Temp\ipykernel_14312\2917587123.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# Text(2.2, 8, 'basic unility of text')

# %%
plt.figure(figsize=(5,4),dpi=120)
plt.plot([1,2,5],[7,8,9])
text = plt.text(x=2.2,# x axis of the text
         y=8, # y axis of the text
         s='basic unility of text', # text
         # font of the text
         fontdict=dict(fontsize=12, color='r',family='monospace',),

         # background box
         bbox={'facecolor': '#74C476', # background color
              'edgecolor':'b',# edge color
               'alpha': 0.5, # transparent
               'pad': 8,# the distance between text and edge
              }

        )

text.set_color('b')# text color

# %%
plt.figure(figsize=(5,4),dpi=120)
plt.plot([1,2,5],[7,8,9])
plt.text(x=2.2,# x axis of the text
         y=8,# y axis of the text
         s='basic unility of text', #text
         # font of the text
         fontdict=dict(fontsize=12, color='r',family='monospace',),

         #background box
         bbox={'facecolor': '#74C476', # background color
              'edgecolor':'b',# edge color
               'alpha': 0.5, # transparent
               'pad': 0.8,# the distance between text and edge 
               'boxstyle':'roundtooth'
              }

        )
# Out:
# Text(2.2, 8, 'basic unility of text')

# %%
plt.figure(figsize=(5,4),dpi=120)
plt.plot([1,2,5],[7,8,9])

plt.annotate('basic unility of annotate', 
             xy=(2, 8),# The posision of arrow sharp

             xytext=(1.0, 8.75),# The position of text

             # Attributes of the arrow
            arrowprops=dict(facecolor='#74C476', 
                            shrink=1,
                            alpha=0.6,
                            width=7,
                            headwidth=40,
                            hatch='--',# Shape of the arrow
                            frac=0.8,
                           ),
            )
# Out:
# Text(1.0, 8.75, 'basic unility of annotate')
# C:\Users\mbieg\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\events.py:93: UserWarning: 'frac' option in 'arrowprops' is no longer supported; use 'headlength' to set the head length in points.
#   func(*args, **kwargs)
# C:\Users\mbieg\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: 'frac' option in 'arrowprops' is no longer supported; use 'headlength' to set the head length in points.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(5,4),dpi=120)
plt.plot([1,2,5],[7,8,9])

plt.annotate('basic unility of annotate', 
             xy=(2, 8),
             xytext=(1.0, 8.75),
             arrowprops=dict(facecolor='#74C476', 
                            alpha=0.6,
                            arrowstyle='-|>',# Shape of the arrow
                             color='r'
                           ),
            )
# Out:
# C:\Users\mbieg\AppData\Local\Temp\ipykernel_14312\2649131512.py:4: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.annotate('basic unility of annotate',
# Text(1.0, 8.75, 'basic unility of annotate')

# %%
plt.figure(figsize=(5,4),dpi=120)
plt.plot([1,2,5],[7,8,9])

plt.annotate('basic unility of annotate', 
             xy=(2, 8),
             xytext=(1.0, 8.75),
             arrowprops=dict(facecolor='#74C476', 
                             alpha=0.6,
                             arrowstyle='-|>',
                             connectionstyle='arc3,rad=0.5',
                             color='r',
                            ),
            )
plt.show()
# Out:
# C:\Users\mbieg\AppData\Local\Temp\ipykernel_14312\2570179841.py:4: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.annotate('basic unility of annotate',

# %%
from matplotlib.text import OffsetFrom
fig, (ax1, ax2) = plt.subplots(1, 2,dpi=120)

bbox_args = dict(boxstyle="round", fc="lightgreen")
arrow_args = dict(arrowstyle="->",color='r')

ax1.annotate('Cupid arrow end at ax1', xy=(.5, .75),
                   xytext=(.5, .3), 
                   ha="center", va="center",
                   bbox=bbox_args,
                   arrowprops=dict(connectionstyle="arc3,rad=0.2",
                                   **arrow_args))

ax1.annotate('Stop here', xy=(.5, .7), 
                   xytext=(.5, .8), 
                   ha="center", va="center",
                   bbox=bbox_args,
                   )

ax2.annotate('Cupid arrow start from ax2',
             xy=(0.85, 0.3), xycoords=ax1.transData,# crossing
             xytext=(10, 10),
             textcoords=OffsetFrom(ax2.bbox, (0, 0), "points"),
             ha="left", va="bottom",
             bbox=bbox_args,
             arrowprops=dict(connectionstyle="arc3,rad=0.5",
                             **arrow_args,

                            ))

ax2.set(xlim=[-2, 2], ylim=[-2, 2])
plt.show()
