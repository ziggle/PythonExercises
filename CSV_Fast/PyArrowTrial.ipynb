# %% [markdown]
# https://itnext.io/the-fastest-way-to-read-a-csv-file-in-pandas-2-0-532c1f978201

# %%
import polars as pl
import pyarrow 
df = pl.read_csv('file.csv').to_pandas()

# %%
# Check the type
##

# %%
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             DR_NO               Date Rptd                DATE OCC  TIME OCC
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230  \
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 699275  230109201  03/23/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1830
# 699276  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 699277  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 699278  230907962  04/10/2023 12:00:00 AM  04/10/2023 12:00:00 AM       426
# 699279  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd
# 0          3    Southwest          377         2     624  \
# 1          1      Central          163         2     624
# 2          1      Central          155         2     845
# 3         15  N Hollywood         1543         2     745
# 4         19      Mission         1998         2     740
# ...      ...          ...          ...       ...     ...
# 699275     1      Central          111         1     440
# 699276    16     Foothill         1663         2     740
# 699277    16     Foothill         1602         1     230
# 699278     9     Van Nuys          933         1     310
# 699279     9     Van Nuys          914         2     745
#
#                                               Crm Cd Desc  ... Status
# 0                                BATTERY - SIMPLE ASSAULT  ...     AO  \
# 1                                BATTERY - SIMPLE ASSAULT  ...     IC
# 2               SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# 3                VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 4       VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# ...                                                   ...  ...    ...
# 699275                 THEFT PLAIN - PETTY ($950 & UNDER)  ...     IC
# 699276  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 699277     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 699278                                           BURGLARY  ...     IC
# 699279           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
#
#          Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4
# 0        Adult Other    624.0      NaN      None     None  \
# 1        Invest Cont    624.0      NaN      None     None
# 2       Adult Arrest    845.0      NaN      None     None
# 3        Invest Cont    745.0    998.0      None     None
# 4        Invest Cont    740.0      NaN      None     None
# ...              ...      ...      ...       ...      ...
# 699275   Invest Cont    440.0      NaN      None     None
# 699276   Invest Cont    740.0      NaN      None     None
# 699277   Invest Cont    230.0      NaN      None     None
# 699278   Invest Cont    310.0      NaN      None     None
# 699279   Invest Cont    745.0      NaN      None     None
#
#                                         LOCATION Cross Street      LAT
# 0        1100 W  39TH                         PL         None  34.0141  \
# 1         700 S  HILL                         ST         None  34.0459
# 2         200 E  6TH                          ST         None  34.0448
# 3        5400    CORTEEN                      PL         None  34.1685
# 4       14400    TITUS                        ST         None  34.2198
# ...                                          ...          ...      ...
# 699275    700 W  CESAR E CHAVEZ               AV         None  34.0606
# 699276  12500    BRANFORD                     ST         None  34.2466
# 699277  12800    FILMORE                      ST         None  34.2790
# 699278  14500    SYLVAN                       ST         None  34.1846
# 699279  14500    HARTLAND                     ST         None  34.1951
#
#              LON
# 0      -118.2978
# 1      -118.2545
# 2      -118.2474
# 3      -118.4019
# 4      -118.4468
# ...          ...
# 699275 -118.2439
# 699276 -118.4054
# 699277 -118.4116
# 699278 -118.4488
# 699279 -118.4487
#
# [699280 rows x 28 columns]
