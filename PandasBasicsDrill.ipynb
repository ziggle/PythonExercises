# %% [markdown]
# https://python.plainenglish.io/python-pandas-library-basics-and-examples-95fd7d5f2b54

# %%
import pandas as pd

# Creating a Pandas Series
s = pd.Series([10, 77, 12, 4, 5])
print("Pandas Series:")
print(s)
print("Index:", s.index)
print("Data type:", s.dtype)
print("Size:", s.size)
print("Values:", s.values)
print("First few elements:")
print(s.head(3))
print("Last few elements:")
print(s.tail(3))
# Out:
# Pandas Series:
# 0    10
# 1    77
# 2    12
# 3     4
# 4     5
# dtype: int64
# Index: RangeIndex(start=0, stop=5, step=1)
# Data type: int64
# Size: 5
# Values: [10 77 12  4  5]
# First few elements:
# 0    10
# 1    77
# 2    12
# dtype: int64
# Last few elements:
# 2    12
# 3     4
# 4     5
# dtype: int64

# %%
# Reading data from a CSV file into a DataFrame
df = pd.read_csv("/path/to/your/file.csv")
print("DataFrame head:")
print(df.head())

# %%
import seaborn as sns

# Loading a sample dataset (Titanic dataset)
df = sns.load_dataset("titanic")

# Quick look at the DataFrame
print("DataFrame head:")
print(df.head())

# Retrieving DataFrame information
print("DataFrame info:")
print(df.info())

# Statistical summary of the DataFrame
print("Statistical summary:")
print(df.describe())

# Counting non-NA values in each column
print("Count of non-NA values:")
print(df.count())

# Checking for null values
print("Number of null values:")
print(df.isnull().sum())

# Checking if there are any null values
print("Any null values?")
print(df.isnull().values.any())

# Describing DataFrame columns, shape, and index
print("DataFrame columns:")
print(df.columns)
print("DataFrame shape:")
print(df.shape)
print("DataFrame index:")
print(df.index)

# Accessing a specific column
print("Accessing a specific column:")
print(df["Name"].head())

# Counting unique values in a column
print("Count unique values in a column:")
print(df["Gender"].value_counts())
# Out:
# DataFrame head:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ...

# %%
# Selecting rows by index range
print("Selecting rows by index range:")
print(df[0:13])

# Dropping rows by index
print("Dropping rows by index:")
print(df.drop(2, axis=0).head())

# Dropping multiple rows by index
delete_indexes = [1, 3, 5, 7]
print("Dropping multiple rows by index:")
print(df.drop(delete_indexes, axis=0).head(10))

# Dropping a column
print("Dropping a column:")
print(df.drop(["deck"], axis=1).head())
# Or
print(df.drop(["deck"], axis=1, inplace=True).head())

# Note: To make changes permanent, use inplace=True parameter or reassign the DataFrame.
# Out:
# Selecting rows by index range:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...
