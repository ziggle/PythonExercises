# %%
import os
import sys
os.path.dirname(sys.executable)
# Out:
# 'c:\\Users\\Mark\\anaconda3'

# %%
import pandas as pd
crimes = pd.read_csv(".\Crimes_-_2001_to_Present.csv")

# %%
(crimes
.sample(500)
.assign(month_name=lambda df:pd.to_datetime(df['Date']).dt.month_name())
.pipe(lambda df:pd.crosstab(index=df['Primary Type'],columns=df.month_name))
)
# Out:
# month_name                        April  August  December  February  January  \
# Primary Type
# ARSON                                 0       0         0         0        1
# ASSAULT                               1       3         4         5        2
# BATTERY                               8       9         3         7       11
# BURGLARY                              5       3         3         2        2
# CRIM SEXUAL ASSAULT                   0       0         0         1        0
# CRIMINAL DAMAGE                       4       2         2         7        4
# CRIMINAL TRESPASS                     1       0         1         4        3
# DECEPTIVE PRACTICE                    4       1         2         1        1
# HOMICIDE                              0       0         0         1        0
# INTERFERENCE WITH PUBLIC OFFICER      2       1         0         0        0
# INTIMIDATION                          0       0         0         1        0
# ...

# %%
(crimes
.sample(500)
.assign(month_name=lambda df:pd.to_datetime(df['Date']).dt.month_name()
        .astype('category')
        .cat.reorder_categories(['January','February','March','April', \
                                 'May','June','July','August','September', \
                                 'October','November','December'], \
                                ordered=True))
.pipe(lambda df:pd.crosstab(index=df['Primary Type'],columns=df.month_name))
)
# Out:
# month_name                        January  February  March  April  May  June  \
# Primary Type
# ARSON                                   0         0      0      0    0     1
# ASSAULT                                 4         1      2      2    6     4
# BATTERY                                13         5      9      9    9     9
# BURGLARY                                3         0      3      3    3     1
# CRIM SEXUAL ASSAULT                     0         0      0      0    0     0
# CRIMINAL DAMAGE                         9         2      4      4    7     8
# CRIMINAL TRESPASS                       0         2      2      2    1     2
# DECEPTIVE PRACTICE                      2         1      0      2    3     1
# HOMICIDE                                0         0      0      0    1     0
# INTERFERENCE WITH PUBLIC OFFICER        0         0      0      0    0     1
# MOTOR VEHICLE THEFT                     1         2      1      2    2     3
# ...
