# %% [markdown]
# https://pub.towardsai.net/the-truly-hardest-of-pandas-pivot-and-melt-clearly-explained-5627d0cf7dc0

# %%
# Load necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Plotting pretty figures and avoid blurry images
# %config InlineBackend.figure_format = 'retina'
# Larger scale for plots in notebooks
sns.set_context('talk')

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Enable multiple cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
df = pd.DataFrame({'New York': [25]})
df
# Out:
#    New York
# 0        25

# %%
df.melt()
# Out:
#    variable  value
# 0  New York     25

# %%
df = pd.DataFrame({'New york': [25], 'Paris': [27], 'London': [30]})
df
# Out:
#    New york  Paris  London
# 0        25     27      30

# %%
df.melt()
# Out:
#    variable  value
# 0  New york     25
# 1     Paris     27
# 2    London     30

# %%
df_larger = pd.DataFrame({
    'New york': [25, 27, 23, 25, 29],
    'Paris': [27, 22, 24, 26, 28],
    'London': [30, 31, 33, 29, 25]
})
df_larger
# Out:
#    New york  Paris  London
# 0        25     27      30
# 1        27     22      31
# 2        23     24      33
# 3        25     26      29
# 4        29     28      25

# %%
df_larger.melt()
# Out:
#     variable  value
# 0   New york     25
# 1   New york     27
# 2   New york     23
# 3   New york     25
# 4   New york     29
# 5      Paris     27
# 6      Paris     22
# 7      Paris     24
# 8      Paris     26
# 9      Paris     28
# 10    London     30
# 11    London     31
# 12    London     33
# 13    London     29
# 14    London     25

# %%
df.melt(var_name='city', value_name='temperature')
# Out:
#        city  temperature
# 0  New york           25
# 1     Paris           27
# 2    London           30

# %%
temperatures = pd.DataFrame({
    'city': ['New York', 'London', 'Paris', 'Berlin', 'Amsterdam'],
    'day1': [23, 25, 27, 26, 24],
    'day2': [22, 21, 25, 26, 23],
    'day3': [26, 25, 24, 27, 23],
    'day4': [23, 21, 22, 26, 27],
    'day5': [27, 26, 27, 24, 28]
})
temperatures
# Out:
#         city  day1  day2  day3  day4  day5
# 0   New York    23    22    26    23    27
# 1     London    25    21    25    21    26
# 2      Paris    27    25    24    22    27
# 3     Berlin    26    26    27    26    24
# 4  Amsterdam    24    23    23    27    28

# %%
temperatures.melt()
# Out:
#    variable      value
# 0      city   New York
# 1      city     London
# 2      city      Paris
# 3      city     Berlin
# 4      city  Amsterdam
# 5      day1         23
# 6      day1         25
# 7      day1         27
# 8      day1         26
# 9      day1         24
# 10     day2         22
# 11     day2         21
# 12     day2         25
# 13     day2         26
# 14     day2         23
# 15     day3         26
# 16     day3         25
# 17     day3         24
# 18     day3         27
# 19     day3         23
# 20     day4         23
# 21     day4         21
# 22     day4         22
# 23     day4         26
# 24     day4         27
# 25     day5         27
# 26     day5         26
# 27     day5         27
# 28     day5         24
# 29     day5         28

# %%
temperatures.melt(id_vars=['city'])
# Out:
#          city variable  value
# 0    New York     day1     23
# 1      London     day1     25
# 2       Paris     day1     27
# 3      Berlin     day1     26
# 4   Amsterdam     day1     24
# 5    New York     day2     22
# 6      London     day2     21
# 7       Paris     day2     25
# 8      Berlin     day2     26
# 9   Amsterdam     day2     23
# 10   New York     day3     26
# 11     London     day3     25
# 12      Paris     day3     24
# 13     Berlin     day3     27
# 14  Amsterdam     day3     23
# 15   New York     day4     23
# 16     London     day4     21
# 17      Paris     day4     22
# 18     Berlin     day4     26
# 19  Amsterdam     day4     27
# 20   New York     day5     27
# 21     London     day5     26
# 22      Paris     day5     27
# 23     Berlin     day5     24
# 24  Amsterdam     day5     28

# %%
temperatures.melt(id_vars=['city'],
                  var_name='date',
                  value_name='temperature').sample(5)
# Out:
#          city  date  temperature
# 14  Amsterdam  day3           23
# 5    New York  day2           22
# 15   New York  day4           23
# 24  Amsterdam  day5           28
# 17      Paris  day4           22

# %%
stocks = pd.read_csv('prices-split-adjusted.csv',
                     usecols=['date', 'symbol', 'open', 'close'],
                     parse_dates=['date'],
                     index_col='date')
stocks.head()
# Out:
#            symbol        open       close
# date
# 2016-01-05   WLTW  123.430000  125.839996
# 2016-01-06   WLTW  125.239998  119.980003
# 2016-01-07   WLTW  116.379997  114.949997
# 2016-01-08   WLTW  115.480003  116.620003
# 2016-01-11   WLTW  117.010002  114.970001

# %%
stocks_small = stocks.sort_index().loc['2016-02-01':'2016-03-01'].reset_index()
stocks_small.head()
# Out:
#         date symbol       open      close
# 0 2016-02-01   JNPR  23.309999  24.330000
# 1 2016-02-01    JWN  48.459999  49.930000
# 2 2016-02-01      K  73.320000  73.589996
# 3 2016-02-01    KEY  11.250000  11.080000
# 4 2016-02-01    KHC  77.370003  77.010002

# %%
melted = reshaped.melt(id_vars=['symbol'])
melted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24408/4046360180.py in <module>
# ----> 1 melted = reshaped.melt(id_vars=['symbol'])
#       2 melted
#
# NameError: name 'reshaped' is not defined
