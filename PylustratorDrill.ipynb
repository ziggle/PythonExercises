# %%
# ?pip install pylustrator
# Out:
# Object `pip install pylustrator` not found.

# %%
import matplotlib.pyplot as plt
fig, ((ax,ax1),(ax2,ax3)) = plt.subplots(2,2,figsize=(8,8))
ax.plot([1,2,3,4,5,6], [10,15,20,30,25,40])
ax1.bar(['a','b','c','d','e'],[10,20,10,5,3])
ax2.pie([3,3,3,3])
ax3.scatter([1,1,4,4,2,3,2.5], [1,4,4,1,2,2,3])
plt.show()

# %%
import matplotlib.pyplot as plt
import pylustrator
pylustrator.start()
fig, ((ax,ax1),(ax2,ax3)) = plt.subplots(2,2,figsize=(8,8))
ax.plot([1,2,3,4,5,6], [10,15,20,30,25,40])
ax1.bar(['a','b','c','d','e'],[10,20,10,5,3])
ax2.pie([3,3,3,3])
ax3.scatter([1,1,4,4,2,3,2.5], [1,4,4,1,2,2,3])
plt.show()
# Out:
# Object `pip install pylustrator` not found.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26584/776743739.py in <module>
#       1 get_ipython().run_line_magic('pinfo', 'pip install pylustrator')
#       2 import matplotlib.pyplot as plt
# ----> 3 import pylustrator
#       4 pylustrator.start()
#       5 fig, ((ax,ax1),(ax2,ax3)) = plt.subplots(2,2,figsize=(8,8))
#
# ModuleNotFoundError: No module named 'pylustrator'
