# %% [markdown]
# https://thiago-bernardes-carvalho.medium.com/easier-subplots-layout-with-pythons-matplotlib-9912f4a5070a

# %%
import matplotlib.pyplot as plt
fig, ((ax,ax1),(ax2,ax3)) = plt.subplots(2,2,figsize=(8,8))
ax.plot([1,2,3,4,5,6], [10,15,20,30,25,40])
ax1.bar(['a','b','c','d','e'],[10,20,10,5,3])
ax2.pie([3,3,3,3])
ax3.scatter([1,1,4,4,2,3,2.5], [1,4,4,1,2,2,3])
plt.show()

# %%
import matplotlib.pyplot as plt
import pylustrator
pylustrator.start()
fig, ((ax,ax1),(ax2,ax3)) = plt.subplots(2,2,figsize=(8,8))
ax.plot([1,2,3,4,5,6], [10,15,20,30,25,40])
ax1.bar(['a','b','c','d','e'],[10,20,10,5,3])
ax2.pie([3,3,3,3])
ax3.scatter([1,1,4,4,2,3,2.5], [1,4,4,1,2,2,3])
plt.show()

# %%
import matplotlib.pyplot as plt
import pylustrator
pylustrator.start()
fig, ((ax,ax1),(ax2,ax3)) = plt.subplots(2,2,figsize=(8,8))
ax.plot([1,2,3,4,5,6], [10,15,20,30,25,40])
ax1.bar(['a','b','c','d','e'],[10,20,10,5,3])
ax2.pie([3,3,3,3])
ax3.scatter([1,1,4,4,2,3,2.5], [1,4,4,1,2,2,3])
#% start: automatic generated code from pylustrator
plt.figure(1).ax_dict = {ax.get_label(): ax for ax in plt.figure(1).axes}
import matplotlib as mpl
plt.figure(1).axes[0].set_position([0.126136, 0.549790, 0.775000, 0.350000])
plt.figure(1).axes[1].set_position([0.126136, 0.050373, 0.352273, 0.431490])
plt.figure(1).axes[2].set_position([0.352789, 0.344957, 0.103146, 0.103146])
plt.figure(1).axes[3].set_position([0.577995, 0.104505, 0.322005, 0.323225])
plt.figure(1).text(0.5, 0.5, 'New Text', transform=plt.figure(1).transFigure)  
# id=plt.figure(1).texts[0].new
plt.figure(1).texts[0].set_position([0.632712, 0.807334])
plt.figure(1).texts[0].set_text("Look here!")
#% end: automatic generated code from pylustrator
plt.show()

# %% [markdown]
# I am not sure how this provides value. I need to investigate how to integrate pyillustrator into my workflow.
