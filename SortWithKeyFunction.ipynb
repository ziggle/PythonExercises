# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
X = np.array([0.6,-0.5,0.4,0.3, -0.35, -0.375])
Y=["Mark","Craig","Tim","Pat","Katee","CJ"]

# %%
fig, ax=plt.subplots(figsize=(8,4))
(pd.Series(X, index=Y)
 .sort_values(key=np.abs)
 .plot.barh(ax=ax)
)
None

# %%
Z=pd.Series(X, index=Y)
print(Z)
display(Z)
# Out:
# Mark     0.600
# Craig   -0.500
# Tim      0.400
# Pat      0.300
# Katee   -0.350
# CJ      -0.375
# dtype: float64
# Mark     0.600
# Craig   -0.500
# Tim      0.400
# Pat      0.300
# Katee   -0.350
# CJ      -0.375
# dtype: float64
